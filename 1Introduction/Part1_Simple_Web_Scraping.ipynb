# %% [markdown]
# # Introduction

# %% [markdown]
# Avant de commencer, parcourer le fichier README.rst

# %% [markdown]
# # Requête HTTP

# %% [markdown]
# Un requête HTTP est une requête basé sur le protocole TCP, elle fait partie de la couche application de la couche OSI. Elle permet d'accéder aux données mise à disposition sur une adresse IP (ou url résolue par un DNS) et un port.
#
# Les deux ports les plus utilisé dans le web sont le 80 pour les sites en HTTP et le 443 pour les sites en HTTPS. HTTPS est une variable du protocole HTTP basé sur le protocole TLS.
#
# Il existe de nombreux types de requêtes selon la convention `REST`:
# - GET
# - POST
# - PUT
# - DELETE
# - UPDATE.
#
# Dans notre cas nous allons utiliser la plupart du temps des GET et potentiellement des POST.
# - Le GET permet comme sont nom l'indique de récupérer des informations en fonction de certain paramètres.
# - Le POST nécéssite un envoie de données pour récupérer des données. Le body du post est, la plupart du temps, envoyé sous la forme d'un objet JSON.
#
# Ces requêtes encapsulent un certain nombre de paramètres qui permettent soient d'identifier une provenance et un utilisateur ou de réaliser différentes actions.

# %%
import requests

# %%
url = "http://www.esiee.fr/"
response = requests.get(url)
response.status_code
# Out:
# 200

# %% [markdown]
# Il existe deux méthodes pour récupérer le contenu de la page :
#
# - `response.text` qui permet de retourner le texte sous la forme d'une chaine de charactères.
# - `response.content` qui permet de récupérer le contenu de la page sous la forme de bytes

# %%
type(response.content)
# Out:
# bytes

# %%
type(response.text)
# Out:
# str

# %% [markdown]
# Pour récupérer les 1000 premiers charactères de la page :

# %%
response.text[0:1000]
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if IE 9]>         <html class="no-js ie9"> <![endif]-->\n<!--[if gt IE 9]><!--> <html class="no-js"> <!--<![endif]-->\n<head profile="http://www.w3.org/1999/xhtml/vocab">\n  <meta name="google-site-verification" content="JnG7DTdhQuWTeSHlWC63CeWpb3WValiOorksYjoYOWI" />\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<meta name="description" content="ESIEE Paris, l’école de l’innovation technologique | Grande école d’ingénieurs\r\nForme dans les domaines des technologies du numérique - Habilitée CTI." />\n<link rel="shortcut icon" href="https://www.esiee.fr/sites/all/themes/custom/esiee_theme/favicon.ico" type="image/vnd.microsoft.icon" />\n  <title>ESIEE Paris, l’école de l’in'

# %% [markdown]
# Pour récupérer les headers HTTP de la réponse :

# %%
response.headers
# Out:
# {'Date': 'Wed, 05 Dec 2018 07:48:22 GMT', 'Server': 'Apache', 'Expires': 'Sun, 19 Nov 1978 05:00:00 GMT', 'Cache-Control': 'no-cache, must-revalidate', 'X-Content-Type-Options': 'nosniff', 'Content-Language': 'fr', 'X-Frame-Options': 'SAMEORIGIN', 'X-Generator': 'Drupal 7 (http://drupal.org)', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'X-Robots-Tag': 'index,follow,noarchive', 'X-XSS-Protection': '1; mode=block', 'X-Download-Options': 'noopen;', 'X-Permitted-Cross-Domain-Policies': 'none', 'Content-Length': '15927', 'Keep-Alive': 'timeout=5, max=150', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=utf-8'}

# %% [markdown]
# On peut modifier les paramêtres de la requête et/ou ses headers. On peut par exemple ajouter un UserAgent et un timeout de 10 secondes:

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers, timeout = 10)
response.content[0:1000]
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\n<!--[if IE 9]>         <html class="no-js ie9"> <![endif]-->\n<!--[if gt IE 9]><!--> <html class="no-js"> <!--<![endif]-->\n<head profile="http://www.w3.org/1999/xhtml/vocab">\n  <meta name="google-site-verification" content="JnG7DTdhQuWTeSHlWC63CeWpb3WValiOorksYjoYOWI" />\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta name="Generator" content="Drupal 7 (http://drupal.org)" />\n<meta name="description" content="ESIEE Paris, l\xe2\x80\x99\xc3\xa9cole de l\xe2\x80\x99innovation technologique | Grande \xc3\xa9cole d\xe2\x80\x99ing\xc3\xa9nieurs\r\nForme dans les domaines des technologies du num\xc3\xa9rique - Habilit\xc3\xa9e CTI." />\n<link rel="shortcut icon" href="https://www.esiee.fr/sites/all/themes/custom/esiee_theme/favicon.ico" type="image/vnd.microsoft.icon" />\n  <title>ESIEE Paris, l\xe2\x80\x99'

# %% [markdown]
# ## Exercice

# %% [markdown]
# ## Exercice 1
#
# - Créer une classe Python permettant de faire des requêtes HTTP.
# - Cette classe doit utiliser toujours le même UserAgent.
# - Le TimeOut sera spécifié à chaque appelle avec une valeur par défaut.
# - Un mécanisme de retry sera mis en place de façon recursive.
#
# ## Exercice 2
#
# - Faire une fonction permettant de supprimer tous les espaces supperflus d'une string
# - Faire une fonction qui prend une string html et renvois une string intelligible (enlever les caractères spéciaux,
# - Récupérer le domaine en fonction d'un url

# %%
class http_request:
    """classe Python permettant de faire des requêtes HTTP"""
    i = 12345
    
    def __init__(self, url, userAgent, timeOut = 10, retries = 3):
        self.url = url
        self.userAgent = userAgent
        self.timeOut = timeOut
        self.headers = {'User-Agent': userAgent}
        self.retries = retries

    def do_request(self):
        success = False
        while not success or self.retries <= 0:
            try :
                return requests.get(url = self.url, headers = self.headers, timeout = self.timeOut)
                success = True
            except Exception as e:
                wait = 1
                self.retries -= 1

# %%
url = "http://www.esiee.fr/"
userAgent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'

x = http_request(url, userAgent)
x.url
print(x.do_request())
# Out:
# <Response [200]>

# %%
import re

"""
Fonction permettant de supprimer tous les espaces supperflus d'une string
"""
def rm_spaces(mystring):
    #rstrip() # strip trailing spaces (end)
    #lstrip() # strip leading spaces (start)
    #strip() # strip leading and trailing (start and end)
    mystring = re.sub(' +', ' ', mystring) # supprime les espaces doublons
    return mystring.strip()

# %%
rm_spaces(" My     String ")
# Out:
# 'My String'

# %%
def intelligible_string(mystring):
    return ''.join(e for e in mystring if e.isalnum())

# %%
intelligible_string("a% . b")
# Out:
# 'ab'

# %%
# simple but not recommended
def get_domain(url):
    return url.split("://")[1].split("/")[0]

# %%
get_domain("http://www.esiee.fr/")
# Out:
# 'www.esiee.fr'

# %% [markdown]
# # Exploitation du HTML

# %% [markdown]
# Ici, il faut récupérer le code HTML d'un site web à partir d'une requête. Lorsque vous avez récupéré le texte d'un site il faut le parser. Pour cela, on utilise BeautifulSoup qui permet de transformer la structure HTML en objet Python. Cela permet de récupérer efficacement les données qui nous intéresse.
#
# Pour les webmasters, le blocage le plus souvent mis en place et un blocage sur le User-Agent. Le User-Agent est un paramètre intégré dans la requête HTTP réalisé par le Navigateur pour envoyer au front des informations basiques :
#
# - la version du Navigateur,
# - la version de l'OS
# - Le type de gestionnaire graphique (Gecko)
# - le type de device utilisé

# %% [markdown]
# Exemple de User Agent :
#
# `Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0`

# %% [markdown]
# Commençons à utiliser `BeautifulSoup`, pour l'installer :

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: beautifulsoup4 in /Users/development/.local/share/virtualenvs/DataEngineerTools-WVBmgKCy/lib/python3.6/site-packages (from bs4) (4.6.0)
# Building wheels for collected packages: bs4
#   Running setup.py bdist_wheel for bs4 ... done
#   Stored in directory: /Users/development/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Pour transformer une requête (requests) en objet BeautifulSoup :

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, "lxml")

# %% [markdown]
# Il se peut qu'un message d'erreur arrive à ce point là si vous n'avez pas la librarie `lxml` installée, pour se faire vous avez juste à lancer la commande suivante :

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /Users/development/.local/share/virtualenvs/DataEngineerTools-WVBmgKCy/lib/python3.6/site-packages (4.1.0)

# %% [markdown]
# Pour trouver tous les liens d'une page on récupère la balise `a` qui permet de gérer les liens en HTML  :

# %%
soup.find_all("a")[0:10]
# Out:
# [<a href="#">
#  <i class="icon-parametres"></i>
#  </a>,
#  <a href="https://gmail.com" target="_blank" title="Webmail ESIEE Paris"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_950.png"/> </i><span>Webmail ESIEE Paris</span></a>,
#  <a href="https://planif.esiee.fr/direct/" target="_blank" title="Emploi du temps général"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1331.png"/> </i><span>Emploi du temps général</span></a>,
#  <a href="https://planif.esiee.fr/jsp/custom/esiee/easyMyPlanning.jsp" target="_blank" title="Emploi du temps individuel"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1332.png"/> </i><span>Emploi du temps individuel</span></a>,
#  <a href="https://intra.esiee.fr" target="_blank" title="Extranet"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_951.png"/> </i><span>Extranet</span></a>,
#  <a href="https://esiee.blackboard.com" target="_blank" title="iCampus"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1311.png"/> </i><span>iCampus</span></a>,
#  <a href="http://e5.onthehub.com/WebStore/Welcome.aspx?vsro=8&amp;ws=45AD823E-799B-E011-969D-0030487D8897&amp;JSEnabled=1" target="_blank" title="Microsoft DreamSpark"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1696.png"/> </i><span>Microsoft DreamSpark</span></a>,
#  <a href="/en">
#  <i>
#  <img alt="English" src="/sites/all/themes/custom/esiee_theme/assets/images/flag-en.png"/>
#  </i>
#  </a>,
#  <a href="https://www.facebook.com/esieeparis" target="_blank">
#  <i class="fa fa-facebook"></i>
#  </a>,
#  <a href="https://twitter.com/ESIEEPARIS" target="_blank">
#  <i class="fa fa-twitter"></i>
#  </a>]

# %% [markdown]
# On peut préciser la classe HTML voulue  pour l'ensemble des `a`:
#
# ```python
# soup.find_all(class_="<CLASS_NAME>")[0:10]
# ```
#
# Ici par exemple:

# %%
soup.find_all(class_="slide")[0:5]
# Out:
# [<div class="slide slide-content">
#  <span class="slide-content-date inline-block"><span class="date-display-single">02.10.2018</span></span>
#  <span class="slide-content-theme inline-block is-uppercase">Journée portes ouvertes</span>
#  <div class="clearfix"></div>
#  <div class="slide-content-img pull-left"><!-- scald=1951:news_thumbnail --><img alt="Jounées portes ouvertes ESIEE Paris 2018-2019" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-jpo2_0.png?itok=beyrHUYj" title="Journées portes ouvertes ESIEE Paris 2018-2019" width="120"/><!-- END scald=1951 --></div>
#  <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/journee-portes-ouvertes-15-decembre-2018">Portes Ouvertes - Samedi 15 décembre 2018 de 13h à 18h</a></span>
#  <div class="clearfix"></div>
#  <p class="slide-content-desc">Bien choisir son école, c'est aussi la rencontrer !</p> </div>,
#  <div class="slide slide-content">
#  <span class="slide-content-date inline-block"><span class="date-display-single">07.12.2018</span></span>
#  <span class="slide-content-theme inline-block is-uppercase">Evènements</span>
#  <div class="clearfix"></div>
#  <div class="slide-content-img pull-left"><!-- scald=1877:news_thumbnail --><img alt="Cérémonie des diplômes ESIEE Paris 2018" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-ceremonie-2.jpg?itok=wh10eMjF" title="Cérémonie des diplômes ESIEE Paris 2018" width="120"/><!-- END scald=1877 --></div>
#  <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/ceremonie-remise-de-diplomes-2018"> Cérémonie de remise des diplômes 2018</a></span>
#  <div class="clearfix"></div>
#  <p class="slide-content-desc">Près de 330 élèves issus de la formation d'ingénieur seront diplômés le 7 décembre prochain.</p> </div>,
#  <div class="slide slide-content">
#  <span class="slide-content-date inline-block"><span class="date-display-single">29.11.2018</span></span>
#  <span class="slide-content-theme inline-block is-uppercase">Evènements</span>
#  <div class="clearfix"></div>
#  <div class="slide-content-img pull-left"><!-- scald=1224:news_thumbnail --><img alt="illustration-table-ronde-filles-amphi.jpg" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-table-ronde-filles-amphi.jpg?itok=V_P7UehK" title="Illustration table ronde - Féminisation du métier d'ingénieur" width="120"/><!-- END scald=1224 --></div>
#  <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/table-ronde-feminisation-metier-ingenieur-2018">Table-ronde "Et Si Ingénieur s'Ecrivait avec un E" avec le soutien d'Elles bougent</a></span>
#  <div class="clearfix"></div>
#  <p class="slide-content-desc">Des lycéens sensibilisés à ESIEE Paris sur la féminisation des études d’ingénieures.</p> </div>,
#  <div class="slide slide-content">
#  <span class="slide-content-date inline-block"><span class="date-display-single">24.11.2018</span></span>
#  <span class="slide-content-theme inline-block is-uppercase">Evènements</span>
#  <div class="clearfix"></div>
#  <div class="slide-content-img pull-left"><!-- scald=1986:news_thumbnail --><img alt="HFLan, le rendez-vous des gamers" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-hflan_1.jpg?itok=8383zB_f" title="HFLan, le rendez-vous des gamers" width="120"/><!-- END scald=1986 --></div>
#  <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/HFLAN-novembre-2018">HFLAN, le rendez-vous incontournable des gamers</a></span>
#  <div class="clearfix"></div>
#  <p class="slide-content-desc">HFLAN, évènement vidéoludique, revient pour la 17e édition les 24 et 25 novembre prochain.</p> </div>,
#  <div class="slide slide-content">
#  <span class="slide-content-date inline-block"><span class="date-display-single">10.11.2018</span></span>
#  <span class="slide-content-theme inline-block is-uppercase">Salons</span>
#  <div class="clearfix"></div>
#  <div class="slide-content-img pull-left"><!-- scald=615:news_thumbnail --><img alt="salon ESIEE Paris" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/etudiant-polo-esiee-salon.jpg?itok=mAuNEvFf" title="salon ESIEE Paris" width="120"/><!-- END scald=615 --></div>
#  <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/salon-etudiants-novembre-2018">Salons étudiants : rendez-vous avec ESIEE Paris !</a></span>
#  <div class="clearfix"></div>
#  <p class="slide-content-desc">Venez vous renseigner sur nos formations. Trois rendez-vous avec ESIEE Paris en novembre.</p> </div>]

# %% [markdown]
# Pour récupérer le text sans les balises HTML :

# %%
soup.text[0:1000]
# Out:
# ' \n\n\n\n\n\n\nESIEE Paris, l’école de l’innovation technologique | Grande école d’ingénieurs | ESIEE Paris\n\n\n\n\n\n<!--/*--><![CDATA[/*><!--*/\n#sliding-popup.sliding-popup-bottom,#sliding-popup.sliding-popup-bottom .eu-cookie-withdraw-banner,.eu-cookie-withdraw-tab{background:#e9e7e2;}#sliding-popup.sliding-popup-bottom.eu-cookie-withdraw-wrapper{background:transparent}#sliding-popup .popup-content #popup-text h1,#sliding-popup .popup-content #popup-text h2,#sliding-popup .popup-content #popup-text h3,#sliding-popup .popup-content #popup-text p,.eu-cookie-compliance-more-button,.eu-cookie-compliance-secondary-button,.eu-cookie-withdraw-tab{color:#48444e !important;}.eu-cookie-withdraw-tab{border-color:#48444e;}\n\n/*]]>*/-->\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\nLes outils ESIEE Paris Webmail ESIEE Paris Emploi du temps général Emploi du temps individuel Extranet iCampus Microsoft DreamSpark \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n menu\nFormations\n\n\nRETOUR menu\nFormations ESIEE ParisIngénieur\n\n\nIngénieur\n'

# %% [markdown]
# ## Exercice
# ### Exercice 3
#
# Améliorer la classe développé précédemment.
#
# - Ajouter une méthode pour récupérer l'objet soup d'un url
# - Récupérer une liste de User Agent et effectuer une rotation aléatoire sur celui à utiliser
# - Utiliser cette classe pour parser une page HTML et récupérer : le titre, tous les H1 (si ils existes), les liens vers les images, les liens sortants vers d'autres sites, et le texte principal.
#
# Parsing d'un sitemaps pour récupérer une listes de liens avec les informations disponibles. -> Stocker dans un dictionnaire et dans un fichier JSON local.

# %%
class http_request:
    """classe Python permettant de faire des requêtes HTTP"""
    i = 12345
    
    def __init__(self, url, userAgent, timeOut = 10, retries = 3):
        self.url = url
        self.userAgent = userAgent
        self.timeOut = timeOut
        self.headers = {'User-Agent': userAgent}
        self.retries = retries

    def do_request(self):
        success = False
        while not success or self.retries <= 0:
            try :
                return requests.get(url = self.url, headers = self.headers, timeout = self.timeOut)
                success = True
            except Exception as e:
                wait = 1
                self.retries -= 1
                
    def soup_url(self):
        response = self.do_request()
        soup = BeautifulSoup(response.text, "lxml")
        #soup = BeautifulSoup(response.content)
        return soup

# %%
import random

url = "http://www.esiee.fr/"
userAgents = [
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36",
    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36",
    "Mozilla/5.0 (Linux; Android 5.1; A37f Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.93 Mobile Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36"
]

x = http_request(url, random.choice(userAgents))
x.url
soup = x.soup_url()

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if IE 9]>         <html class="no-js ie9"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js"> <!--<![endif]-->
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta content="JnG7DTdhQuWTeSHlWC63CeWpb3WValiOorksYjoYOWI" name="google-site-verification"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <meta content="ESIEE Paris, l’école de l’innovation technologique | Grande école d’ingénieurs
# Forme dans les domaines des technologies du numérique - Habilitée CTI." name="description"/>
# <link href="https://www.esiee.fr/sites/all/themes/custom/esiee_theme/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <title>ESIEE Paris, l’école de l’innovation technologique | Grande école d’ingénieurs | ESIEE Paris</title>
# <meta content="width=device-width, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_0nehMyndYv683LPew3BuGYArd7h9_M6uCOHIYpQyNdo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_UoOfC8xl0qY9o7fDVnXCtzCGUr2B4iosZ2hiF0bdLnQ.css" media="all" rel="stylesheet" type="text/css"/>
# <style media="all" type="text/css">
# <!--/*--><![CDATA[/*><!--*/
# #sliding-popup.sliding-popup-bottom,#sliding-popup.sliding-popup-bottom .eu-cookie-withdraw-banner,.eu-cookie-withdraw-tab{background:#e9e7e2;}#sliding-popup.sliding-popup-bottom.eu-cookie-withdraw-wrapper{background:transparent}#sliding-popup .popup-content #popup-text h1,#sliding-popup .popup-content #popup-text h2,#sliding-popup .popup-content #popup-text h3,#sliding-popup .popup-content #popup-text p,.eu-cookie-compliance-more-button,.eu-cookie-compliance-secondary-button,.eu-cookie-withdraw-tab{color:#48444e !important;}.eu-cookie-withdraw-tab{border-color:#48444e;}
#
# /*]]>*/-->
# </style>
# <link href="https://www.esiee.fr/sites/default/files/css/css_jnWPMB5qTfBTXw7RTtwiJVUcsZqZxwK4a7jadESk0dM.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_N2m8XERalJCC_CzmYWb1LY7y1R6M2JJcg9uQKP-dzf8.css" media="print" rel="stylesheet" type="text/css"/>
# <script src="https://www.esiee.fr/sites/default/files/js/js_gsRojzcXYRtFv8QHp89dxyJVklpAK8YiSqSpCQgUdak.js" type="text/javascript"></script>
# </head>
# <body class="html front not-logged-in one-sidebar sidebar-first page-esiee-homepage i18n-fr page-home">
# <div class="toolbar">
# <div class="for-mobile">
# <div class="block block-esiee" id="block-esiee-esiee-header-search--2">
# <form accept-charset="UTF-8" action="/" class="form-horizontal f-left" id="form-search" method="post" onsubmit='if(this.keyword.value == "Rechercher...") this.keyword.value=""'><div> <input class="form-control form-text form-control" id="edit-keyword--2" maxlength="128" name="keyword" onblur='if(this.value == "") this.value="Rechercher..."' onfocus='if(this.value == "Rechercher...") this.value=""' size="60" type="text" value="Rechercher..."/>
# <input class="form-submit" id="edit-submit--3" name="op" type="submit" value=""/><input name="form_build_id" type="hidden" value="form-suq2sldnTrxWfTYHqA35a6sKF34ZzInMtLlfcJZWdTE"/>
# <input name="form_id" type="hidden" value="esiee_global_search_form"/>
# </div></form></div>
# </div>
# <ul>
# <li class="parameters">
# <a href="#">
# <i class="icon-parametres"></i>
# </a>
# <div class="parameters-tools">
# <div class="parameters-tools-inner">
# <p class="title">Les outils ESIEE Paris</p><ul><li><a href="https://gmail.com" target="_blank" title="Webmail ESIEE Paris"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_950.png"/> </i><span>Webmail ESIEE Paris</span></a></li><li><a href="https://planif.esiee.fr/direct/" target="_blank" title="Emploi du temps général"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1331.png"/> </i><span>Emploi du temps général</span></a></li><li><a href="https://planif.esiee.fr/jsp/custom/esiee/easyMyPlanning.jsp" target="_blank" title="Emploi du temps individuel"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1332.png"/> </i><span>Emploi du temps individuel</span></a></li><li><a href="https://intra.esiee.fr" target="_blank" title="Extranet"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_951.png"/> </i><span>Extranet</span></a></li><li><a href="https://esiee.blackboard.com" target="_blank" title="iCampus"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1311.png"/> </i><span>iCampus</span></a></li><li class="last"><a href="http://e5.onthehub.com/WebStore/Welcome.aspx?vsro=8&amp;ws=45AD823E-799B-E011-969D-0030487D8897&amp;JSEnabled=1" target="_blank" title="Microsoft DreamSpark"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1696.png"/> </i><span>Microsoft DreamSpark</span></a></li></ul> </div>
# </div>
# </li>
# <li>
# <a href="/en">
# <i>
# <img alt="English" src="/sites/all/themes/custom/esiee_theme/assets/images/flag-en.png"/>
# </i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://www.facebook.com/esieeparis" target="_blank">
# <i class="fa fa-facebook"></i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://twitter.com/ESIEEPARIS" target="_blank">
# <i class="fa fa-twitter"></i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://www.linkedin.com/edu/school?id=20041&amp;trk=tyah&amp;trkInfo=idx%3A4-1-4%2CtarId%3A1425998561386%2Ctas%3Aesiee+paris" target="_blank">
# <i class="fa fa-linkedin"></i>
# </a>
# </li>
# <li class="hide-mobile youtube">
# <a href="http://www.youtube.com/esieeparis" target="_blank">
# <i class="fa fa-youtube"></i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://www.instagram.com/esieeparis/" target="_blank">
# <i class="fa fa-instagram"></i>
# </a>
# </li>
# <li class="for-mobile social-networks">
# <a href="#toolbar-footer">
# <i><img alt="Réseaux sociaux" src="/sites/all/themes/custom/esiee_theme/assets/images/icon-socialnetworks.png"/></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="l-page">
# <header>
# <div class="inner clearfix">
# <div class="logo f-left"><a href="/fr" title="Page d'accueil"><img alt="ESIEE Paris" src="https://www.esiee.fr/sites/all/themes/custom/esiee_theme/logo.png"/></a></div>
# <div class="menu">
# <a class="btn-menu js-btn-menu" href="#" title=""><span class="fa fa-reorder"></span> menu</a>
# <ul><li class="formations lev0"><a class="js-link-lev0" href="https://www.esiee.fr/fr/formations" id="851">Formations</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations">Formations ESIEE Paris</a></li><li class="with-level"><a class="js-link-lev" href="#" id="880">Ingénieur</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Ingénieur</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/premier-cycle">Premier cycle</a></li><li class="with-level"><a class="js-link-lev" href="#" id="881">Le cycle ingénieur</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Le cycle ingénieur</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur">Le cycle ingénieur ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/enseignements-premiere-annee">Enseignements de 1ère année</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/enseignements-deuxieme-troisieme-annee">Enseignements de 2e et 3e année</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/profils-metiers">Profils métiers</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="886">Filières</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Filières</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres">8 filières, 1 diplôme</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/informatique">Informatique</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/cybersecurite-systemes-information">Cybersécurité des Systèmes d'information</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle">Datascience et intelligence artificielle</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-embarques">Systèmes embarqués</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques">Systèmes électroniques</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel">Génie industriel</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante">Biotechnologies et e-santé</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/energie">Energie</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/emplois-et-salaires">Emplois et salaires</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/frais-scolarites/aides-financieres">Frais de scolarité ingénieur et aides financières</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/stages">Stages</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/admission/Ingenieur">Admissions</a></li><li><a href="https://www.esiee.fr/fr/contact-ingenieur">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="893">Ingénieur par apprentissage</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Ingénieur par apprentissage</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage">Devenir ingénieur par l'apprentissage</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1437">Réseaux et sécurité - architecture et internet des objets</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Réseaux et sécurité - architecture et internet des objets</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite">Réseaux et sécurité - architecture et internet des objets</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite/debouches">Débouchés</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1438">Systèmes embarqués - transports et objets intelligents</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Systèmes embarqués - transports et objets intelligents</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques">Systèmes embarqués - transports et objets intelligents</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques/debouches">Débouchés</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1439">Informatique et applications - ingénierie 3D et technologie des médias</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Informatique et applications - ingénierie 3D et technologie des médias</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications">Informatique et applications - ingénierie graphique et technologies 3D</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications/debouches">Débouchés</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1766">Génie industriel - Supply chain et numérique</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Génie industriel - Supply chain et numérique</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel">Génie industriel - Supply chain et numérique</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel/debouches">Débouchés</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/mode-emploi">Apprentissage : mode d'emploi</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/admission/Ingenieur-par-apprentissage">Admissions</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/site-cergy">Site de Cergy</a></li><li><a href="https://www.esiee.fr/fr/contact-ingenieur-par-apprentissage">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="894">Masters internationaux</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Masters internationaux</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux">Cinq masters internationaux</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/msc-management-information-systems">M.Sc. Management-Information Systems</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/master-computer-science-diplome-ingenieur">International Master of Computer Science</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/master-of-electronics">International Master of Electronics</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/master-wireless-communicant-sensors">Master of Wireless Communicant Sensors</a></li><li><a href="https://www.esiee.fr/fr/contact-masters-internationaux">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="895">Mastères spécialisés</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Mastères spécialisés</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises">Mastère spécialisé ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises/innovation-technologique-management-projet">Innovation technologique et management de projets</a></li><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises/admission/Masteres-specialises">Admissions</a></li><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises/frais-de-scolarite">Frais de scolarité mastères spécialisés</a></li><li><a href="https://www.esiee.fr/fr/contact-masteres-specialises">Contact</a></li></ul></div></div></li></ul></div></div></li><li class="espace-etudiants lev0"><a class="js-link-lev0" href="#" id="852">Espace étudiants</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante">La vie étudiante</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1409">L'associatif</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">L'associatif</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Espace étudiants</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/bureau-des-eleves">Bureau des élèves</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/junior-esiee">Junior ESIEE</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/sport">Sport</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/clubs-associations">Clubs et associations</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/logements">Logements</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/campus-descartes">Campus Descartes</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/relais-handicap">Relais handicap</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1423">Equipements</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Equipements</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Espace étudiants</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/equipements/centre-de-langues">Le centre de langues</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/equipements/informatique">Informatique</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1462">Bibliothèque</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Bibliothèque</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Espace étudiants</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque">Bibliothèque ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/informations-pratiques">Informations pratiques</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/livres-revues">Livres et revues</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1471">Ressources électroniques</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Ressources électroniques</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Bibliothèque</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/ressources-electroniques">Ressources électroniques</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/ressources-electroniques/sciences-et-techniques">Sciences et techniques</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/informations-entreprises">Informations sur les entreprises</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/ressources-electroniques/presse">Presse</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1467">Services</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Services</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Bibliothèque</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/services/aide-personnalise-recherche">Aide personnalisée à la recherche</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/services/pret-ouvrages">Prêt d'ouvrages</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/contact-biblioth%C3%A8que">Contact</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/videotheque">Vidéothèque</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/financer-vos-etudes">Financer vos études</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiant/restauration">Restauration</a></li></ul></div></div></li><li class="ecole lev0"><a class="js-link-lev0" href="#" id="1382">L'école</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/qui-sommes-nous">Qui sommes nous ?</a></li><li><a href="https://www.esiee.fr/fr/gouvernance">Gouvernance</a></li><li><a href="https://www.esiee.fr/fr/ecole/conseil-scientifique">Conseil Scientifique</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1482">Les départements d'enseignements et de recherche</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Les départements d'enseignements et de recherche</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR L'école</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignants/4-departements">4 départements</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/informatique">Informatique</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/ingenierie-systemes">Ingénierie des systèmes</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/sante-energie-environnement">Santé, énergie, environnement</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/management-technologies-langues">Management de la technologie et langues</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1365">Corps enseignant</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Corps enseignant</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR L'école</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/corps-enseignant/enseigner-a-esiee-paris">Enseigner à ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/ecole/les-enseignants-chercheurs">Les enseignants-chercheurs</a></li><li><a href="https://www.esiee.fr/fr/ecole/corps-enseignant/cv-corps-professoral">CV du corps professoral</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1550">Les salles blanches</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Les salles blanches</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR L'école</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches">Les salles blanches</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1064">Equipements et procédés</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Equipements et procédés</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Les salles blanches</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes">Équipements et Procédés</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/photolithographie">Photolithographie</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/traitements-thermiques">Traitements thermiques</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/depots-couches-minces">Dépôts de couches minces</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/electrodeposition">Electrodéposition</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/gravures-plasma">Gravures plasma</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/gravure-humide-nettoyage">Gravure humide et nettoyage</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/scellement-de-substrats">Scellement de substrats</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/metrologie">Métrologie</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/plateforme-sem-fib">Plate-forme SEM/FIB</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/packaging">Packaging</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/recherche-collaborations">Recherche et collaborations</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipe">Equipe</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/plateforme-recherche-collaborative-feder">Plateforme de recherche collaborative - FEDER</a></li><li><a href="https://www.esiee.fr/fr/contact-salles-blanches">Contact</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/ecole/esiee-connect/consortium">Le Consortium ESIEE Connect</a></li><li><a href="https://www.esiee.fr/fr/ecole/esiee-connect">ESIEE Connect</a></li></ul></div></div></li><li class="recherche lev0"><a class="js-link-lev0" href="#" id="854">La recherche</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche">Accueil Recherche</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1563">La recherche à ESIEE Paris</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">La recherche à ESIEE Paris</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR La recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/recherche-esiee-paris">La recherche à ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/partenariats-academiques">Partenariats académiques</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/partenariats-entreprise">Partenariats entreprise</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1573">Grands domaines</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Grands domaines</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR La recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines">3 grands domaines</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines/ville-durable">Ville durable</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines/sante">Santé</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines/tic-et-societe">STIC et société</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="https://www.esiee.fr/fr/la-recherche" id="1502">Thèmes de recherche</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Thèmes de recherche</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR La recherche</a>
# <ul><li class="with-level"><a class="js-link-lev" href="#" id="1503">Informatique, image, signal</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Informatique, image, signal</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal">Informatique, image, signal</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/architecture-parallelisme-realite-virtuelle">Architecture et parallélisme pour l'imagerie et la réalité virtuelle</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/geometrie-algorithmique">Géométrie discrète, géométrie algorithmique </a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/morphologie-mathematique-traitement-image">Morphologie mathématique et traitement d'images </a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/optimisation-modelisation-apprentissage">Optimisation, modélisation et apprentissage </a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/traitement-signal">Traitement du signal</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1506">Capteurs, santé, énergie, environnement</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Capteurs, santé, énergie, environnement</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement">Capteurs, santé, énergie, environnement</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/microsystemes-analyse-environnement-ville-durable">Microsystèmes pour l'analyse de l'environnement et la ville durable</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/technologies-sante">Technologies pour la santé</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/micro-dispositif-materiaux-nanostructurees-recuperation-energie">Micro-dispositifs et matériaux nanostructurées pour la récupération d'énergie</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/systemes-energetiques-ville-durable">Systèmes énergétiques pour la ville durable</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1508">Electronique, communication</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Electronique, communication</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication">Electronique, communication</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/architectures-algorithmes-communications-radios-localisation">Architectures et algorithmes pour les communications radios et la localisation</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/composants-circuits-systemes-communications-radios-optiques">Composants et circuits pour les systèmes de communications radios et optiques</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/electronique-micro-systemes-instrumentation-systems-mesures">Electronique associée aux micro-systèmes, instrumentation et systèmes de mesures</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1509">Systèmes embarqués, réseaux, manufacturing</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Systèmes embarqués, réseaux, manufacturing</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing">Systèmes embarqués, réseaux, manufacturing</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/systemes-temps-reel-optimisation-energie">Systèmes temps réel : ordonnancement temps réel, optimisation de l'énergie, méthodologie et outils de conception</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/optimisation-multi-couches-reseaux">Optimisation inter-couches des réseaux</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/modeles-decisionnels-dynamiques-systemes-manufacturiers">Vers des modèles décisionnels dynamiques pour les systèmes manufacturiers</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1510">Management de l'innovation</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Management de l'innovation</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation">Management de l'innovation</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/innovations-rupture-marches-connaissance">Innovations de rupture et marchés de la connaissance</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/management-projets-innovants">Management de projets innovants</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/entrepreneuriat-financement-innovation">Entrepreneuriat et financement de l'innovation</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/perpectives-mondialisation-changements-institutionnels">Perspectives de la mondialisation et changements institutionnels</a></li></ul></div></div></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/la-recherche/equipements">Équipements</a></li><li><a href="https://www.esiee.fr/fr/esiee_search/person">Équipe de recherche</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/formations-par-la-recherche">Formations par la recherche</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/formalites-accueil">Formalités d'accueil</a></li><li><a href="https://www.esiee.fr/fr/recherche/actualites">Actualité de la recherche</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/publications-esiee">Publications 2017-2018</a></li><li><a href="https://www.esiee.fr/fr/recherche/publications">Publications avant 2016</a></li><li><a href="https://www.esiee.fr/fr/contact-recherche">Contact</a></li></ul></div></div></li><li class="entreprises lev0"><a class="js-link-lev0" href="#" id="855">Entreprises</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/entreprises">L'entreprise au cœur de l'enseignement</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1397">Recrutez nos étudiants</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Recrutez nos étudiants</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Entreprises</a>
# <ul><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants">Recrutez nos étudiants</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/formations">Formations</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/apprentissage">Apprentissage</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/stages">Stages</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/premier-emploi">1er emploi</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/evenements">Evénements entreprises / étudiants</a></li><li><a href="https://www.esiee.fr/fr/entreprises/deposer-offre-emploi-stage-apprentissage">Déposez une offre d'emploi, de stage et d'apprentissage</a></li><li><a href="https://www.esiee.fr/fr/contact-pole-carriere">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1406">Devenez partenaire</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Devenez partenaire</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Entreprises</a>
# <ul><li><a href="https://www.esiee.fr/fr/entreprises/devenez-partenaire/creez-un-partenariat">Créez un partenariat</a></li><li><a href="https://www.esiee.fr/fr/entreprises/devenez-partenaire/recherche-a-esiee-paris">R&amp;D de ESIEE Paris</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/entreprises/formez-vos-equipes">Formez vos équipes</a></li><li><a href="https://www.esiee.fr/fr/entreprises/devenez-partenaire/versez-votre-taxe-apprentissage">Taxe d'apprentissage</a></li><li><a href="https://www.esiee.fr/fr/entreprises/enteprises-mecene">Entreprise mécène</a></li><li><a href="https://www.esiee.fr/fr/entreprises/utilisez-nos-plateformes-technologiques">Utilisez nos plateformes technologiques</a></li><li><a href="https://www.esiee.fr/fr/entreprises/reseau-des-anciens">Réseau des anciens</a></li><li><a href="https://www.esiee.fr/fr/location-despaces">Louez nos espaces</a></li><li><a href="https://www.esiee.fr/fr/contact-entreprises">Contact</a></li><li><a href="https://www.esiee.fr/fr/entreprises/deposer-offre-emploi-stage-apprentissage">Déposez une offre d'emploi, de stage et d'apprentissage</a></li></ul></div></div></li><li class="last international lev0"><a class="js-link-lev0" href="#" id="856">International</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/international/large-ouverture">Une large ouverture à l'international</a></li><li><a href="https://www.esiee.fr/fr/international/partenaires-academiques">Partenaires académiques</a></li><li><a href="https://www.esiee.fr/fr/international/etudier-a-letranger">Etudier à l'étranger</a></li><li><a href="https://www.esiee.fr/fr/international/accueil-etudiants-en-echanges">Etudiants en échange</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux">Masters internationaux</a></li><li><a href="https://www.esiee.fr/fr/international/reseau-ni">Réseau N+i</a></li><li><a href="https://www.esiee.fr/fr/les-dipl%C3%B4m%C3%A9s-%C3%A0-linternational">Les diplômés à l'international</a></li><li><a href="https://www.esiee.fr/fr/contact-international">Contact </a></li><li><a href="https://www.esiee.fr/fr/campus-%C3%A0-l%C3%A9tranger">Campus à l'étranger</a></li></ul></div></div></li></ul> </div>
# <div class="block block-esiee" id="block-esiee-esiee-header-search">
# <form accept-charset="UTF-8" action="/" class="form-horizontal f-left" id="form-search" method="post" onsubmit='if(this.keyword.value == "Rechercher...") this.keyword.value=""'><div> <input class="form-control form-text form-control" id="edit-keyword" maxlength="128" name="keyword" onblur='if(this.value == "") this.value="Rechercher..."' onfocus='if(this.value == "Rechercher...") this.value=""' size="60" type="text" value="Rechercher..."/>
# <input class="form-submit" id="edit-submit--2" name="op" type="submit" value=""/><input name="form_build_id" type="hidden" value="form-NLxpxrel7OjyUqReAeFv4WgWYAsxHaU8Jko7x6pvEfc"/>
# <input name="form_id" type="hidden" value="esiee_global_search_form"/>
# </div></form></div>
# </div>
# </header>
# <section class="clearfix l-main">
# <section class="l-content-top">
# </section>
# <div class="tabs inner"></div>
# <div class="block block-system" id="block-system-main">
# <div class="inner">
# <div class="block-tabs clearfix">
# <ul class="bxslider-tabs"> <li class="">
# <div class="tab-background"><div class="image"><img alt="home-bandeau-1.png" src="https://www.esiee.fr/sites/default/files/home-bandeau-1_0.png" title="home-bandeau-1.png"/></div></div>
# <div class="tab-content">
# <div class="block-tabs-title">Ingénieur</div>
# <div class="block-tabs-buttons clearfix"><p><a class="btn btn-default" href="/fr/formations/ingenieur/ingenieur-esiee-paris">Découvrir la formation</a></p><p><a class="btn btn-default" href="/fr/formations/ingenieur/filieres">Filières et métiers</a></p><p><a class="btn btn-default" href="/fr/formations/ingenieur/emplois-et-salaires">Emplois et salaires</a></p><p><a class="btn btn-default btn-orange" href="/fr/formations/ingenieur/admission/Ingenieur">Admissions &amp; inscriptions</a></p></div>
# </div> </li>
# <li class="">
# <div class="tab-background"><div class="image"><img alt="Illustration International Masters home" src="https://www.esiee.fr/sites/default/files/home-bandeau-4.png" title="Illustration International Masters home"/></div></div>
# <div class="tab-content">
# <div class="block-tabs-title">Ingénieur par apprentissage</div>
# <div class="block-tabs-buttons clearfix"><p><a href="/fr/formations/ingenieur-par-apprentissage"><span class="btn btn-default">Découvrir la formation</span></a></p><p><a class="btn btn-default" href="/fr/formations/ingenieur/emplois-et-salaires">Emplois et salaires</a></p><p><a class="btn btn-default" href="/fr/formations/ingenieur-par-apprentissage/mode-emploi">Apprentissage : mode d'emploi</a></p><p><a class="btn btn-default btn-orange" href="/fr/formations/ingenieur-par-apprentissage/admission/Ingenieur-par-apprentissage">Admissions &amp; inscriptions</a></p></div>
# </div> </li>
# <li class="">
# <div class="tab-background"><div class="image"><img alt="Illustration Mastères Spécialisés home" height="343" src="https://www.esiee.fr/sites/default/files/home-bandeau-3.png" title="Illustration Mastères Spécialisés home" width="1018"/></div></div>
# <div class="tab-content">
# <div class="block-tabs-title">Mastères spécialisés</div>
# <div class="block-tabs-buttons clearfix"><p><a class="btn btn-default" href="/fr/formations/masteres-specialises">Découvrir la formation</a></p><p><a class="btn btn-default btn-orange" href="/fr/formations/masteres-specialises/admission/Masteres-specialises">Admissions &amp; inscriptions</a></p></div>
# </div> </li>
# <li class="">
# <div class="tab-background"><div class="image"><img alt="Illustration Ingénieur par apprentissage - Home page" height="344" src="https://www.esiee.fr/sites/default/files/illustration-ingenieurs-app.-home.png" title="Illustration Ingénieur par apprentissage - Home page" width="1018"/></div></div>
# <div class="tab-content">
# <div class="block-tabs-title">Programmes internationaux</div>
# <div class="block-tabs-buttons clearfix"><p><a class="btn btn-default" href="/fr/formations/masters-internationaux">Découvrir la formation</a></p><p><a class="btn btn-default btn-orange" href="/en/programmes/international-masters/how-to-apply">Admissions &amp; inscriptions</a></p></div>
# </div> </li>
# </ul>
# <ul class="clearfix" id="bxslider-pager">
# <li class="is-uppercase is-underlined block-tabs-nav-title">Formations</li>
# <li><a data-slide-index="0" href="#">Ingénieur</a></li>
# <li><a data-slide-index="1" href="#">Ingénieur par apprentissage</a></li>
# <li><a data-slide-index="2" href="#">Mastères spécialisés</a></li>
# <li><a data-slide-index="3" href="#">Programmes internationaux</a></li>
# </ul>
# </div>
# <div class="block-tabs for-mobile-portrait">
# <div class="is-uppercase block-tabs-nav-title">Formations</div>
# <ul>
# <li>
# <div class="tab-background"><div class="image"><img alt="home-bandeau-1.png" src="https://www.esiee.fr/sites/default/files/home-bandeau-1_0.png" title="home-bandeau-1.png"/></div></div>
# <div class="tab-content">
# <a class="block-tabs-link" href="fr/formations/ingenieur/ingenieur-esiee-paris"><i class="fa fa-chevron-right"></i></a>
# <div class="block-tabs-title">Ingénieur</div>
# </div>
# </li>
# <li>
# <div class="tab-background"><div class="image"><img alt="Illustration International Masters home" src="https://www.esiee.fr/sites/default/files/home-bandeau-4.png" title="Illustration International Masters home"/></div></div>
# <div class="tab-content">
# <a class="block-tabs-link" href="fr/formations/ingenieur-par-apprentissage"><i class="fa fa-chevron-right"></i></a>
# <div class="block-tabs-title">Ingénieur par apprentissage</div>
# </div>
# </li>
# <li>
# <div class="tab-background"><div class="image"><img alt="Illustration Mastères Spécialisés home" height="343" src="https://www.esiee.fr/sites/default/files/home-bandeau-3.png" title="Illustration Mastères Spécialisés home" width="1018"/></div></div>
# <div class="tab-content">
# <a class="block-tabs-link" href="fr/formations/masteres-specialises"><i class="fa fa-chevron-right"></i></a>
# <div class="block-tabs-title">Mastères spécialisés</div>
# </div>
# </li>
# <li>
# <div class="tab-background"><div class="image"><img alt="Illustration Ingénieur par apprentissage - Home page" height="344" src="https://www.esiee.fr/sites/default/files/illustration-ingenieurs-app.-home.png" title="Illustration Ingénieur par apprentissage - Home page" width="1018"/></div></div>
# <div class="tab-content">
# <a class="block-tabs-link" href="fr/formations/masters-internationaux"><i class="fa fa-chevron-right"></i></a>
# <div class="block-tabs-title">Programmes internationaux</div>
# </div>
# </li>
# </ul>
# </div>
# <div class="panel-separator"></div>
# <div class="pull-right rss-link">
# <a href="fr/rss/news" title="RSS"><i class="fa fa-rss-square"></i></a>
# </div>
# <div class="page-title-inline">
# <h2>Actualités</h2>
# </div>
# <a class="link-more" href="/fr/esiee_search/news/home">Lire plus d'actualités</a>
# <div class="responsive-slider-news">
# <div class="slide slide-content">
# <span class="slide-content-date inline-block"><span class="date-display-single">02.10.2018</span></span>
# <span class="slide-content-theme inline-block is-uppercase">Journée portes ouvertes</span>
# <div class="clearfix"></div>
# <div class="slide-content-img pull-left"><!-- scald=1951:news_thumbnail --><img alt="Jounées portes ouvertes ESIEE Paris 2018-2019" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-jpo2_0.png?itok=beyrHUYj" title="Journées portes ouvertes ESIEE Paris 2018-2019" width="120"/><!-- END scald=1951 --></div>
# <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/journee-portes-ouvertes-15-decembre-2018">Portes Ouvertes - Samedi 15 décembre 2018 de 13h à 18h</a></span>
# <div class="clearfix"></div>
# <p class="slide-content-desc">Bien choisir son école, c'est aussi la rencontrer !</p> </div>
# <div class="slide slide-content">
# <span class="slide-content-date inline-block"><span class="date-display-single">07.12.2018</span></span>
# <span class="slide-content-theme inline-block is-uppercase">Evènements</span>
# <div class="clearfix"></div>
# <div class="slide-content-img pull-left"><!-- scald=1877:news_thumbnail --><img alt="Cérémonie des diplômes ESIEE Paris 2018" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-ceremonie-2.jpg?itok=wh10eMjF" title="Cérémonie des diplômes ESIEE Paris 2018" width="120"/><!-- END scald=1877 --></div>
# <span class="slide-content-title"><a class="is-uppercase" href="/fr/actualite/ceremonie-remise-de-diplomes-2018"> Cérémonie de remise des diplômes 2018</a></span>
# <div class="clearfix"></div>
# <p class="slide-content-desc">Près de 330 élèves issus de la formation d'ingénieur seront diplômés le 7 décembre prochain.</p> </div>
# <div class="slide slide-content">
# <span class="slide-content-date inline-block"><span class="date-display-single">29.11.2018</span></span>
# <span class="slide-content-theme inline-block is-uppercase">Evènements</span>
# <div class="clearfix"></div>
# <div class="slide-content-img pull-left"><!-- scald=1224:news_thumbnail --><img alt="illustration-table-ronde-filles-amphi.jpg" height="90" src="https://www.esiee.fr/sites/default/files/styles/news/public/thumbnails/image/illustration-table-ronde-filles-amphi.jpg?itok=V_P7UehK" title="Illustration table ronde - Féminisation du métier d'ingénieur" width="120"/><!-- END scald=1224 --></div>
# ...
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques">
# <!-- scald=1972:skill_thumbnail --><img alt="Filière Systèmes électroniques" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/thumbnails/image/systemes-electroniques.jpg?itok=MNp66bp8" title="Filière Systèmes électroniques" width="207"/><!-- END scald=1972 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques">Systèmes électroniques</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques">Lire la suite</a></div>
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle">
# <!-- scald=898:skill_thumbnail --><img alt="illustration-data-reseaux.jpg" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/illustration-data-reseaux.jpg?itok=6gaT9afn" title="Data et réseaux" width="207"/><!-- END scald=898 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle">Datascience et intelligence artificielle</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle">Lire la suite</a></div>
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel">
# <!-- scald=197:skill_thumbnail --><img alt="Illustration Filière Génie industriel - Chaine de production" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/ill-fil-genieindus-12997candreimerkulovcciparisiledefrance.jpg?itok=NN_nEhue" title="Illustration Filière Génie industriel - Chaine de production" width="207"/><!-- END scald=197 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel">Génie industriel</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel">Lire la suite</a></div>
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante">
# <!-- scald=201:skill_thumbnail --><img alt="Illustration Filière Biotechnologies et e-sante - Microscope" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/ill-fil-bio-11118cuwimages_cciparisidf.jpg?itok=pGETF_w_" title="Illustration Filière Biotechnologies et e-sante - Microscope" width="207"/><!-- END scald=201 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante">Biotechnologies et e-santé</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante">Lire la suite</a></div>
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/energie">
# <!-- scald=192:skill_thumbnail --><img alt="Illustration Filière Energie - Eolienne et Panneaux solaires" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/ill-fil-energies.jpg?itok=rl0sINUe" title="Illustration Filière Energie - Eolienne et Panneaux solaires" width="207"/><!-- END scald=192 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/energie">Energie</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur/filieres/energie">Lire la suite</a></div>
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications">
# <!-- scald=211:skill_thumbnail --><img alt="Illustration Filière Informatique et Applications - Conception voiture en 3D" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/ill-fil-3d-voiture.jpg?itok=tFcX4Tlu" title="Illustration Filière Informatique et Applications - Conception voiture en 3D" width="207"/><!-- END scald=211 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications">Informatique 3D</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage">Ingénieur par apprentissage</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications">Lire la suite</a></div>
# <div class="slide slide-content">
# <div class="slide-content-img">
# <a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite">
# <!-- scald=210:skill_thumbnail --><img alt="Illustration Filière Réseaux et Sécurité" height="125" src="https://www.esiee.fr/sites/default/files/styles/skill/public/ill-fil-systinfo-13709classedesignencciparisidf.jpeg?itok=KQBsTtUL" title="Illustration Filière Réseaux et Sécurité" width="207"/><!-- END scald=210 -->
# </a>
# </div>
# <span class="slide-content-info">
# <a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite">Réseaux et sécurité</a>
# </span>
# <span class="slide-content-theme">
# <a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage">Ingénieur par apprentissage</a>
# </span>
# <a class="slide-content-link is-uppercase" href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite">Lire la suite</a></div>
# </div>
# <div class="responsive-slider-2-pagination">
# <div class="responsive-slider-2-prev responsive-slider-2-nav"></div>
# <div class="responsive-slider-2-pager"></div>
# <div class="responsive-slider-2-next responsive-slider-2-nav active"></div>
# </div>
# </div></div>
# </section>
# <footer>
# <div class="inner clearfix">
# <div class="block block-bean" id="block-bean-adresse-esiee-footer">
# <div class="footer-col-1 pull-left">
# <span class="footer-col-1-title">ESIEE Paris</span>
# <p>2 boulevard Blaise Pascal<br/>Cité Descartes<br/>BP 99<br/>93162 Noisy-le-Grand Cedex</p><p>Tel : 01 45 92 65 00<br/> </p>
# </div></div>
# <div class="block block-esiee" id="block-esiee-esiee-footer-menu">
# <div class="footer-col-2 pull-left">
# <ul class="menu-footer"><li class="first leaf"><a href="/fr/acces">Plan d'accès</a></li>
# <li class="leaf"><a href="/fr/presse">Presse</a></li>
# <li class="leaf"><a href="/fr/nous-rencontrer">Nous rencontrer</a></li>
# <li class="leaf"><a href="/fr/jour-des-projets">Le Jour des Projets</a></li>
# <li class="leaf"><a href="/fr/brochures">Brochures</a></li>
# <li class="leaf"><a href="/fr/videotheque">Vidéothèque</a></li>
# <li class="leaf"><a href="/fr/location-despaces">Location d'espaces</a></li>
# <li class="leaf"><a href="http://www.esiee.fr/fr/ecole/corps-enseignant/enseigner-a-esiee-paris">Enseigner à ESIEE</a></li>
# <li class="leaf"><a href="/fr/reseaux-sociaux">Réseaux sociaux</a></li>
# <li class="leaf"><a href="/fr/mentions-legales">Mentions Légales</a></li>
# <li class="leaf"><a href="http://www.cci-paris-idf.fr/marches-publics-dematerialises-cci-paris-ile-de-france">Marchés publics</a></li>
# <li class="last leaf"><a href="/fr/plan-du-site">Plan du site</a></li>
# </ul></div>
# <div class="clearfix"></div></div>
# <div class="block block-esiee" id="block-esiee-esiee-footer-contact">
# <div class="pull-left"><a class="footer-contact" href="/fr/contact">Contacter ESIEE Paris</a></div></div>
# <div class="block block-bean" id="block-bean-footer-logo-partenaire">
# <div class="pull-right logo-cci">
# <a href="http://www.cci-paris-idf.fr" target="_blank">
# <div class="image"><img alt="logo-cci-paris.png" src="https://www.esiee.fr/sites/default/files/logo-cci-paris.png" title="logo-cci-paris.png"/></div>
# </a></div></div>
# </div>
# </footer>
# </div>
# <div class="toolbar toolbar-footer" id="toolbar-footer">
# <ul>
# <li class="">
# <a href="https://www.facebook.com/esieeparis" target="_blank">
# <i class="fa fa-facebook"></i>
# </a>
# </li>
# <li class="">
# <a href="https://twitter.com/ESIEEPARIS" target="_blank">
# <i class="fa fa-twitter"></i>
# </a>
# </li>
# <li class="">
# <a href="https://www.linkedin.com/edu/school?id=20041&amp;trk=tyah&amp;trkInfo=idx%3A4-1-4%2CtarId%3A1425998561386%2Ctas%3Aesiee+paris" target="_blank">
# <i class="fa fa-linkedin"></i>
# </a>
# </li>
# <li class="youtube">
# <a href="http://www.youtube.com/esieeparis" target="_blank">
# <i class="fa fa-youtube"></i>
# </a>
# </li>
# <li class="">
# <a href="https://www.instagram.com/esieeparis/" target="_blank">
# <i class="fa fa-instagram"></i>
# </a>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# window.jQuery || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/jquery/1.10/jquery.min.js'>\x3C/script>")
# //--><!]]>
# </script>
# <script src="//code.jquery.com/jquery-1.10.2.min.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_vSmhpx_T-AShyt_WMW5_TcwwxJP1imoVOa8jvwL_mxE.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_-DBi72BBkS07mO2sU0Cs9m7v_qf0DaCcgVHrnEXxtcg.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_ajcq4b424tCd76JV2fK93OSs1gAJefWX8KKKtAiej7w.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_qfS4rnmbGrHTIq8FrbJZZDDAlQ4MdxtSunnqdNx0HTs.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# function euCookieComplianceLoadScripts() {}
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var eu_cookie_compliance_cookie_name = "";
# //--><!]]>
# </script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_gPqjYq7fqdMzw8-29XWQIVoDSWTmZCGy9OqaHppNxuQ.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-4033468-1", {"cookieDomain":"auto"});ga("send", "pageview");
# //--><!]]>
# </script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_OsAg78UG2iuku7zfmjPTt17v-frHcMfBCRHX_V7u2r0.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_2PmUXh0PE5NzhnjBZseSzCTfPzCIsMn5irM9A2r3Y4c.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_6KurW8SbFvAKc4Ke5ypFvfbGMSJnBh0H6QlA2mVtSbM.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"fr\/","ajaxPageState":{"theme":"esiee_theme","theme_token":"iUfs5efGxSxLj_uUh3kARmt_yxSo4e-_zk5fMgUIuPo"},"googleCSE":{"cx":"","language":"","resultsWidth":600,"domain":"www.google.com"},"scaldFile":{"path":"sites\/all\/modules\/contrib\/scald_file\/scald_file.css"},"urlIsAjaxTrusted":{"\/":true},"eu_cookie_compliance":{"popup_enabled":1,"popup_agreed_enabled":0,"popup_hide_agreed":0,"popup_clicking_confirmation":false,"popup_scrolling_confirmation":false,"popup_html_info":"\u003Cdiv\u003E\n  \u003Cdiv class =\u0022custom-cookie-popup popup-content info\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\n      \u003Cp\u003EEn naviguant sur notre site, vous acceptez l\u0026#39;utilisation de cookies pour vous proposer une navigation optimale et nous permettre de r\u00e9aliser des statistiques de visites. Pour en savoir plus et param\u00e9trer les cookies, visiter \u003Ca href=\u0022\/fr\/mentions-legales\u0022\u003Ela page des mentions l\u00e9gales de ESIEE Paris\u003C\/a\u003E\u003C\/p\u003E    \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button\u0022\u003EAccepter\u003C\/button\u003E\n    \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","use_mobile_message":false,"mobile_popup_html_info":"\u003Cdiv\u003E\n  \u003Cdiv class =\u0022custom-cookie-popup popup-content info\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\n          \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button\u0022\u003EAccepter\u003C\/button\u003E\n    \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E\n","mobile_breakpoint":"768","popup_html_agreed":"\u003Cdiv\u003E\r\n  \u003Cdiv class =\u0022popup-content agreed\u0022\u003E\r\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\r\n      \u003Ch2\u003EThank you for accepting cookies\u003C\/h2\u003E\u003Cp\u003EYou can now hide this message or find out more about cookies.\u003C\/p\u003E    \u003C\/div\u003E\r\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\r\n      \u003Cbutton type=\u0022button\u0022 class=\u0022hide-popup-button eu-cookie-compliance-hide-button\u0022\u003EMasquer\u003C\/button\u003E\r\n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button-thank-you\u0022 \u003EMore info\u003C\/button\u003E\r\n          \u003C\/div\u003E\r\n  \u003C\/div\u003E\r\n\u003C\/div\u003E","popup_use_bare_css":false,"popup_height":"auto","popup_width":"100%","popup_delay":1000,"popup_link":"\/fr\/fr\/fr\/mentions-legales","popup_link_new_window":1,"popup_position":null,"popup_language":"fr","store_consent":true,"better_support_for_screen_readers":0,"reload_page":0,"domain":"","popup_eu_only_js":0,"cookie_lifetime":"100","cookie_session":false,"disagree_do_not_show_popup":0,"method":"opt_in","whitelisted_cookies":"","withdraw_markup":"\u003Cbutton type=\u0022button\u0022 class=\u0022eu-cookie-withdraw-tab\u0022\u003E\u003C\/button\u003E\r\n\u003Cdiv class=\u0022eu-cookie-withdraw-banner\u0022\u003E\r\n  \u003Cdiv class=\u0022popup-content info\u0022\u003E\r\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\r\n          \u003C\/div\u003E\r\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\r\n      \u003Cbutton type=\u0022button\u0022 class=\u0022eu-cookie-withdraw-button\u0022\u003E\u003C\/button\u003E\r\n    \u003C\/div\u003E\r\n  \u003C\/div\u003E\r\n\u003C\/div\u003E\r\n","withdraw_enabled":false},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"},"esiee_sliders":{"training_d ...
# //--><!]]>
# </script>
# <script src="https://code.jquery.com/jquery-migrate-1.2.1.js"></script>
# </body>
# </html>

# %%
#soup.find_all(class_="slide")[0:5]

print("titre :")
print(soup.title.string, "\n")

print("tous les H1 :")
#print(soup.find_all("h1"), "\n")

print("liens vers les images :")
#print(soup.find_all("img"), "\n")

print("liens sortants vers d'autres sites :")
#print(soup.find_all("a", href=True), "\n")
for link in soup.find_all('a', href=True):
    print(link['href'])

#print("texte principal :")
#print(soup.text)
# Out:
# titre :
# ESIEE Paris, l’école de l’innovation technologique | Grande école d’ingénieurs | ESIEE Paris
#
# tous les H1 :
# liens vers les images :
# liens sortants vers d'autres sites :
# #
# https://gmail.com
# https://planif.esiee.fr/direct/
# https://planif.esiee.fr/jsp/custom/esiee/easyMyPlanning.jsp
# https://intra.esiee.fr
# https://esiee.blackboard.com
# http://e5.onthehub.com/WebStore/Welcome.aspx?vsro=8&ws=45AD823E-799B-E011-969D-0030487D8897&JSEnabled=1
# /en
# https://www.facebook.com/esieeparis
# https://twitter.com/ESIEEPARIS
# https://www.linkedin.com/edu/school?id=20041&trk=tyah&trkInfo=idx%3A4-1-4%2CtarId%3A1425998561386%2Ctas%3Aesiee+paris
# http://www.youtube.com/esieeparis
# https://www.instagram.com/esieeparis/
# #toolbar-footer
# /fr
# #
# https://www.esiee.fr/fr/formations
# #
# https://www.esiee.fr/fr/formations
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/premier-cycle
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur
# https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/enseignements-premiere-annee
# https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/enseignements-deuxieme-troisieme-annee
# https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/profils-metiers
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur/filieres
# https://www.esiee.fr/fr/formations/ingenieur/filieres/informatique
# https://www.esiee.fr/fr/formations/ingenieur/filieres/cybersecurite-systemes-information
# https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel
# https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante
# https://www.esiee.fr/fr/formations/ingenieur/filieres/energie
# https://www.esiee.fr/fr/formations/ingenieur/emplois-et-salaires
# https://www.esiee.fr/fr/formations/ingenieur/frais-scolarites/aides-financieres
# https://www.esiee.fr/fr/formations/ingenieur/stages
# https://www.esiee.fr/fr/formations/ingenieur/admission/Ingenieur
# https://www.esiee.fr/fr/contact-ingenieur
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite/programme-des-enseignements
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite/debouches
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques/programme-des-enseignements
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques/debouches
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications/programme-des-enseignements
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications/debouches
# #
# #
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel/programme-des-enseignements
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel/debouches
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/mode-emploi
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/admission/Ingenieur-par-apprentissage
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/site-cergy
# https://www.esiee.fr/fr/contact-ingenieur-par-apprentissage
# #
# #
# https://www.esiee.fr/fr/formations/masters-internationaux
# https://www.esiee.fr/fr/formations/masters-internationaux/msc-management-information-systems
# https://www.esiee.fr/fr/formations/masters-internationaux/master-computer-science-diplome-ingenieur
# https://www.esiee.fr/fr/formations/masters-internationaux/master-of-electronics
# https://www.esiee.fr/fr/formations/masters-internationaux/master-wireless-communicant-sensors
# https://www.esiee.fr/fr/contact-masters-internationaux
# #
# #
# https://www.esiee.fr/fr/formations/masteres-specialises
# https://www.esiee.fr/fr/formations/masteres-specialises/innovation-technologique-management-projet
# https://www.esiee.fr/fr/formations/masteres-specialises/admission/Masteres-specialises
# https://www.esiee.fr/fr/formations/masteres-specialises/frais-de-scolarite
# https://www.esiee.fr/fr/contact-masteres-specialises
# #
# #
# https://www.esiee.fr/fr/espace-etudiants/vie-etudiante
# #
# #
# https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/bureau-des-eleves
# https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/junior-esiee
# https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/sport
# https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/clubs-associations
# https://www.esiee.fr/fr/espace-etudiants/logements
# https://www.esiee.fr/fr/espace-etudiants/campus-descartes
# https://www.esiee.fr/fr/espace-etudiants/relais-handicap
# #
# #
# https://www.esiee.fr/fr/espace-etudiants/equipements/centre-de-langues
# https://www.esiee.fr/fr/espace-etudiants/equipements/informatique
# #
# #
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque/informations-pratiques
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque/livres-revues
# #
# #
# https://www.esiee.fr/fr/espace-etudiants/ressources-electroniques
# https://www.esiee.fr/fr/espace-etudiants/ressources-electroniques/sciences-et-techniques
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque/informations-entreprises
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque/ressources-electroniques/presse
# #
# #
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque/services/aide-personnalise-recherche
# https://www.esiee.fr/fr/espace-etudiants/bibliotheque/services/pret-ouvrages
# https://www.esiee.fr/fr/contact-biblioth%C3%A8que
# https://www.esiee.fr/fr/videotheque
# https://www.esiee.fr/fr/espace-etudiants/financer-vos-etudes
# https://www.esiee.fr/fr/espace-etudiant/restauration
# #
# #
# https://www.esiee.fr/fr/qui-sommes-nous
# https://www.esiee.fr/fr/gouvernance
# https://www.esiee.fr/fr/ecole/conseil-scientifique
# #
# #
# https://www.esiee.fr/fr/ecole/departements-enseignants/4-departements
# https://www.esiee.fr/fr/ecole/departements-enseignements/informatique
# https://www.esiee.fr/fr/ecole/departements-enseignements/ingenierie-systemes
# https://www.esiee.fr/fr/ecole/departements-enseignements/sante-energie-environnement
# https://www.esiee.fr/fr/ecole/departements-enseignements/management-technologies-langues
# #
# #
# https://www.esiee.fr/fr/ecole/corps-enseignant/enseigner-a-esiee-paris
# https://www.esiee.fr/fr/ecole/les-enseignants-chercheurs
# https://www.esiee.fr/fr/ecole/corps-enseignant/cv-corps-professoral
# #
# #
# https://www.esiee.fr/fr/ecole/salles-blanches
# #
# #
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/photolithographie
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/traitements-thermiques
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/depots-couches-minces
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/electrodeposition
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/gravures-plasma
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/gravure-humide-nettoyage
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/scellement-de-substrats
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/metrologie
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/plateforme-sem-fib
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/packaging
# https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/recherche-collaborations
# https://www.esiee.fr/fr/ecole/salles-blanches/equipe
# https://www.esiee.fr/fr/ecole/salles-blanches/plateforme-recherche-collaborative-feder
# https://www.esiee.fr/fr/contact-salles-blanches
# https://www.esiee.fr/fr/ecole/esiee-connect/consortium
# https://www.esiee.fr/fr/ecole/esiee-connect
# #
# #
# https://www.esiee.fr/fr/la-recherche
# #
# #
# https://www.esiee.fr/fr/la-recherche/recherche-esiee-paris
# https://www.esiee.fr/fr/la-recherche/partenariats-academiques
# https://www.esiee.fr/fr/la-recherche/partenariats-entreprise
# #
# #
# https://www.esiee.fr/fr/la-recherche/grands-domaines
# https://www.esiee.fr/fr/la-recherche/grands-domaines/ville-durable
# https://www.esiee.fr/fr/la-recherche/grands-domaines/sante
# https://www.esiee.fr/fr/la-recherche/grands-domaines/tic-et-societe
# https://www.esiee.fr/fr/la-recherche
# #
# #
# #
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/architecture-parallelisme-realite-virtuelle
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/geometrie-algorithmique
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/morphologie-mathematique-traitement-image
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/optimisation-modelisation-apprentissage
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/traitement-signal
# #
# #
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/microsystemes-analyse-environnement-ville-durable
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/technologies-sante
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/micro-dispositif-materiaux-nanostructurees-recuperation-energie
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/systemes-energetiques-ville-durable
# #
# #
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/architectures-algorithmes-communications-radios-localisation
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/composants-circuits-systemes-communications-radios-optiques
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/electronique-micro-systemes-instrumentation-systems-mesures
# #
# #
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/systemes-temps-reel-optimisation-energie
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/optimisation-multi-couches-reseaux
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/modeles-decisionnels-dynamiques-systemes-manufacturiers
# #
# #
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/innovations-rupture-marches-connaissance
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/management-projets-innovants
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/entrepreneuriat-financement-innovation
# https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/perpectives-mondialisation-changements-institutionnels
# https://www.esiee.fr/fr/la-recherche/equipements
# https://www.esiee.fr/fr/esiee_search/person
# https://www.esiee.fr/fr/la-recherche/formations-par-la-recherche
# https://www.esiee.fr/fr/la-recherche/formalites-accueil
# https://www.esiee.fr/fr/recherche/actualites
# https://www.esiee.fr/fr/la-recherche/publications-esiee
# https://www.esiee.fr/fr/recherche/publications
# https://www.esiee.fr/fr/contact-recherche
# #
# #
# https://www.esiee.fr/fr/entreprises
# #
# #
# https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants
# https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/formations
# https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/apprentissage
# https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/stages
# https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/premier-emploi
# https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/evenements
# https://www.esiee.fr/fr/entreprises/deposer-offre-emploi-stage-apprentissage
# https://www.esiee.fr/fr/contact-pole-carriere
# #
# #
# https://www.esiee.fr/fr/entreprises/devenez-partenaire/creez-un-partenariat
# https://www.esiee.fr/fr/entreprises/devenez-partenaire/recherche-a-esiee-paris
# https://www.esiee.fr/fr/entreprises/formez-vos-equipes
# https://www.esiee.fr/fr/entreprises/devenez-partenaire/versez-votre-taxe-apprentissage
# https://www.esiee.fr/fr/entreprises/enteprises-mecene
# https://www.esiee.fr/fr/entreprises/utilisez-nos-plateformes-technologiques
# https://www.esiee.fr/fr/entreprises/reseau-des-anciens
# https://www.esiee.fr/fr/location-despaces
# https://www.esiee.fr/fr/contact-entreprises
# https://www.esiee.fr/fr/entreprises/deposer-offre-emploi-stage-apprentissage
# #
# #
# https://www.esiee.fr/fr/international/large-ouverture
# https://www.esiee.fr/fr/international/partenaires-academiques
# https://www.esiee.fr/fr/international/etudier-a-letranger
# https://www.esiee.fr/fr/international/accueil-etudiants-en-echanges
# https://www.esiee.fr/fr/formations/masters-internationaux
# https://www.esiee.fr/fr/international/reseau-ni
# https://www.esiee.fr/fr/les-dipl%C3%B4m%C3%A9s-%C3%A0-linternational
# https://www.esiee.fr/fr/contact-international
# https://www.esiee.fr/fr/campus-%C3%A0-l%C3%A9tranger
# /fr/formations/ingenieur/ingenieur-esiee-paris
# /fr/formations/ingenieur/filieres
# /fr/formations/ingenieur/emplois-et-salaires
# /fr/formations/ingenieur/admission/Ingenieur
# /fr/formations/ingenieur-par-apprentissage
# /fr/formations/ingenieur/emplois-et-salaires
# /fr/formations/ingenieur-par-apprentissage/mode-emploi
# /fr/formations/ingenieur-par-apprentissage/admission/Ingenieur-par-apprentissage
# /fr/formations/masteres-specialises
# /fr/formations/masteres-specialises/admission/Masteres-specialises
# /fr/formations/masters-internationaux
# /en/programmes/international-masters/how-to-apply
# #
# #
# #
# #
# fr/formations/ingenieur/ingenieur-esiee-paris
# fr/formations/ingenieur-par-apprentissage
# fr/formations/masteres-specialises
# fr/formations/masters-internationaux
# fr/rss/news
# /fr/esiee_search/news/home
# /fr/actualite/journee-portes-ouvertes-15-decembre-2018
# /fr/actualite/ceremonie-remise-de-diplomes-2018
# /fr/actualite/table-ronde-feminisation-metier-ingenieur-2018
# /fr/actualite/HFLAN-novembre-2018
# /fr/actualite/salon-etudiants-novembre-2018
# /fr/actualite/se-preparer-au-concours-puissance-alpha-2019
# /fr/actualite/future-days-2018
# /fr/actualite/forum-descartes-2018
# /fr/actualite/game-jam-esiee-itescia-2018
# /fr/actualite/rentree-2018-cybersecurite-intelligence-artificielle
# /fr/actualite/journees-tremplin-pour-l-emploi-2018
# /fr/actualite/etudiant-esiee-distinction-euroskills-2018
# /fr/actualite/trophee-des-femmes-de-l-industrie-2018
# https://www.esiee.fr/fr/la-recherche
# https://www.esiee.fr/fr/entreprises
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/nous-rencontrer
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/nous-rencontrer
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# http://www.esiee.fr/fr/entreprises/les-parrains-esiee-paris
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/nous-rencontrer
# https://www.esiee.fr/fr/formations/ingenieur/filieres/informatique
# https://www.esiee.fr/fr/formations/ingenieur/filieres/informatique
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/informatique
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/cybersecurite-systemes-information
# https://www.esiee.fr/fr/formations/ingenieur/filieres/cybersecurite-systemes-information
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/cybersecurite-systemes-information
# https://www.esiee.fr/fr/formations/ingenieur/filieres/energie
# https://www.esiee.fr/fr/formations/ingenieur/filieres/energie
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/energie
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle
# https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle
# https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel
# https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel
# https://www.esiee.fr/fr/formations/masteres-specialises/innovation-technologique-management-projet
# https://www.esiee.fr/fr/formations/masteres-specialises/innovation-technologique-management-projet
# https://www.esiee.fr/fr/formations/masteres-specialises
# https://www.esiee.fr/fr/formations/masteres-specialises/innovation-technologique-management-projet
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques
# https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante
# https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante
# https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris
# https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante
# https://www.esiee.fr/fr/formations/masteres-specialises/e-sante
# https://www.esiee.fr/fr/formations/masteres-specialises/e-sante
# https://www.esiee.fr/fr/formations/masteres-specialises
# https://www.esiee.fr/fr/formations/masteres-specialises/e-sante
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage
# https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications
# /fr/acces
# /fr/presse
# /fr/nous-rencontrer
# /fr/jour-des-projets
# /fr/brochures
# /fr/videotheque
# /fr/location-despaces
# http://www.esiee.fr/fr/ecole/corps-enseignant/enseigner-a-esiee-paris
# /fr/reseaux-sociaux
# /fr/mentions-legales
# http://www.cci-paris-idf.fr/marches-publics-dematerialises-cci-paris-ile-de-france
# /fr/plan-du-site
# /fr/contact
# http://www.cci-paris-idf.fr
# https://www.facebook.com/esieeparis
# https://twitter.com/ESIEEPARIS
# https://www.linkedin.com/edu/school?id=20041&trk=tyah&trkInfo=idx%3A4-1-4%2CtarId%3A1425998561386%2Ctas%3Aesiee+paris
# http://www.youtube.com/esieeparis
# https://www.instagram.com/esieeparis/

# %%
x = http_request("https://www.esiee.fr/sitemap.xml", random.choice(userAgents))
x.url
soup = x.soup_url()

elements = soup.findAll("url")
urls = [elem.find("loc").string for elem in elements]

#print(urls)
limit = 2
urls_content = {}
for url in urls:
    urls_content[url] = http_request(url, random.choice(userAgents)).soup_url()
    limit -= 1
    if limit <= 0 : break

print(urls_content)
# Out:
# {'https://www.esiee.fr/fr/formations': <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]--><!--[if IE 9]>         <html class="no-js ie9"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js"> <!--<![endif]-->
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta content="JnG7DTdhQuWTeSHlWC63CeWpb3WValiOorksYjoYOWI" name="google-site-verification"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
# <link href="https://www.esiee.fr/sites/all/themes/custom/esiee_theme/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <title>Formations | ESIEE Paris</title>
# <meta content="width=device-width, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_0nehMyndYv683LPew3BuGYArd7h9_M6uCOHIYpQyNdo.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_UoOfC8xl0qY9o7fDVnXCtzCGUr2B4iosZ2hiF0bdLnQ.css" media="all" rel="stylesheet" type="text/css"/>
# <style media="all" type="text/css">
# <!--/*--><![CDATA[/*><!--*/
# #sliding-popup.sliding-popup-bottom,#sliding-popup.sliding-popup-bottom .eu-cookie-withdraw-banner,.eu-cookie-withdraw-tab{background:#e9e7e2;}#sliding-popup.sliding-popup-bottom.eu-cookie-withdraw-wrapper{background:transparent}#sliding-popup .popup-content #popup-text h1,#sliding-popup .popup-content #popup-text h2,#sliding-popup .popup-content #popup-text h3,#sliding-popup .popup-content #popup-text p,.eu-cookie-compliance-more-button,.eu-cookie-compliance-secondary-button,.eu-cookie-withdraw-tab{color:#48444e !important;}.eu-cookie-withdraw-tab{border-color:#48444e;}
#
# /*]]>*/-->
# </style>
# <link href="https://www.esiee.fr/sites/default/files/css/css_jnWPMB5qTfBTXw7RTtwiJVUcsZqZxwK4a7jadESk0dM.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.esiee.fr/sites/default/files/css/css_N2m8XERalJCC_CzmYWb1LY7y1R6M2JJcg9uQKP-dzf8.css" media="print" rel="stylesheet" type="text/css"/>
# <script src="https://www.esiee.fr/sites/default/files/js/js_gsRojzcXYRtFv8QHp89dxyJVklpAK8YiSqSpCQgUdak.js" type="text/javascript"></script>
# </head>
# <body class="html not-front not-logged-in one-sidebar sidebar-first page-esiee-training-index i18n-fr page-ingenieurs rub-formations">
# <div class="toolbar">
# <div class="for-mobile">
# <div class="block block-esiee" id="block-esiee-esiee-header-search--2">
# <form accept-charset="UTF-8" action="/fr/formations" class="form-horizontal f-left" id="form-search" method="post" onsubmit='if(this.keyword.value == "Rechercher...") this.keyword.value=""'><div> <input class="form-control form-text form-control" id="edit-keyword--2" maxlength="128" name="keyword" onblur='if(this.value == "") this.value="Rechercher..."' onfocus='if(this.value == "Rechercher...") this.value=""' size="60" type="text" value="Rechercher..."/>
# <input class="form-submit" id="edit-submit--3" name="op" type="submit" value=""/><input name="form_build_id" type="hidden" value="form-uJmBbK9LzHhgZ_i-KZReJBgq3AMYdOSqubC9_kYDHW8"/>
# <input name="form_id" type="hidden" value="esiee_global_search_form"/>
# </div></form></div>
# </div>
# <ul>
# <li class="parameters">
# <a href="#">
# <i class="icon-parametres"></i>
# </a>
# <div class="parameters-tools">
# <div class="parameters-tools-inner">
# <p class="title">Les outils ESIEE Paris</p><ul><li><a href="https://gmail.com" target="_blank" title="Webmail ESIEE Paris"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_950.png"/> </i><span>Webmail ESIEE Paris</span></a></li><li><a href="https://planif.esiee.fr/direct/" target="_blank" title="Emploi du temps général"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1331.png"/> </i><span>Emploi du temps général</span></a></li><li><a href="https://planif.esiee.fr/jsp/custom/esiee/easyMyPlanning.jsp" target="_blank" title="Emploi du temps individuel"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1332.png"/> </i><span>Emploi du temps individuel</span></a></li><li><a href="https://intra.esiee.fr" target="_blank" title="Extranet"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_951.png"/> </i><span>Extranet</span></a></li><li><a href="https://esiee.blackboard.com" target="_blank" title="iCampus"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1311.png"/> </i><span>iCampus</span></a></li><li class="last"><a href="http://e5.onthehub.com/WebStore/Welcome.aspx?vsro=8&amp;ws=45AD823E-799B-E011-969D-0030487D8897&amp;JSEnabled=1" target="_blank" title="Microsoft DreamSpark"><i><img alt="" src="https://www.esiee.fr/sites/default/files/menu_icons/menu_icon_1696.png"/> </i><span>Microsoft DreamSpark</span></a></li></ul> </div>
# </div>
# </li>
# <li>
# <a href="/en/programmes">
# <i>
# <img alt="English" src="/sites/all/themes/custom/esiee_theme/assets/images/flag-en.png"/>
# </i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://www.facebook.com/esieeparis" target="_blank">
# <i class="fa fa-facebook"></i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://twitter.com/ESIEEPARIS" target="_blank">
# <i class="fa fa-twitter"></i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://www.linkedin.com/edu/school?id=20041&amp;trk=tyah&amp;trkInfo=idx%3A4-1-4%2CtarId%3A1425998561386%2Ctas%3Aesiee+paris" target="_blank">
# <i class="fa fa-linkedin"></i>
# </a>
# </li>
# <li class="hide-mobile youtube">
# <a href="http://www.youtube.com/esieeparis" target="_blank">
# <i class="fa fa-youtube"></i>
# </a>
# </li>
# <li class="hide-mobile ">
# <a href="https://www.instagram.com/esieeparis/" target="_blank">
# <i class="fa fa-instagram"></i>
# </a>
# </li>
# <li class="for-mobile social-networks">
# <a href="#toolbar-footer">
# <i><img alt="Réseaux sociaux" src="/sites/all/themes/custom/esiee_theme/assets/images/icon-socialnetworks.png"/></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="l-page">
# <header>
# <div class="inner clearfix">
# <div class="logo f-left"><a href="/fr" title="Page d'accueil"><img alt="ESIEE Paris" src="https://www.esiee.fr/sites/all/themes/custom/esiee_theme/logo.png"/></a></div>
# <div class="menu">
# <a class="btn-menu js-btn-menu" href="#" title=""><span class="fa fa-reorder"></span> menu</a>
# <ul><li class="formations active-trail lev0"><a class="js-link-lev0" href="https://www.esiee.fr/fr/formations" id="851">Formations</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations">Formations ESIEE Paris</a></li><li class="with-level"><a class="js-link-lev" href="#" id="880">Ingénieur</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Ingénieur</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur/ingenieur-esiee-paris">Ingénieur ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/premier-cycle">Premier cycle</a></li><li class="with-level"><a class="js-link-lev" href="#" id="881">Le cycle ingénieur</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Le cycle ingénieur</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur">Le cycle ingénieur ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/enseignements-premiere-annee">Enseignements de 1ère année</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/enseignements-deuxieme-troisieme-annee">Enseignements de 2e et 3e année</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/cycle-ingenieur/profils-metiers">Profils métiers</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="886">Filières</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Filières</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres">8 filières, 1 diplôme</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/informatique">Informatique</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/cybersecurite-systemes-information">Cybersécurité des Systèmes d'information</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/datascience-intelligence-artificielle">Datascience et intelligence artificielle</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-embarques">Systèmes embarqués</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/systemes-electroniques">Systèmes électroniques</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/genie-industriel">Génie industriel</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/biotechnologies-esante">Biotechnologies et e-santé</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/filieres/energie">Energie</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/emplois-et-salaires">Emplois et salaires</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/frais-scolarites/aides-financieres">Frais de scolarité ingénieur et aides financières</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/stages">Stages</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur/admission/Ingenieur">Admissions</a></li><li><a href="https://www.esiee.fr/fr/contact-ingenieur">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="893">Ingénieur par apprentissage</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Ingénieur par apprentissage</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage">Devenir ingénieur par l'apprentissage</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1437">Réseaux et sécurité - architecture et internet des objets</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Réseaux et sécurité - architecture et internet des objets</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite">Réseaux et sécurité - architecture et internet des objets</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/reseaux-securite/debouches">Débouchés</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1438">Systèmes embarqués - transports et objets intelligents</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Systèmes embarqués - transports et objets intelligents</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques">Systèmes embarqués - transports et objets intelligents</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/systemes-embarques/debouches">Débouchés</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1439">Informatique et applications - ingénierie 3D et technologie des médias</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Informatique et applications - ingénierie 3D et technologie des médias</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications">Informatique et applications - ingénierie graphique et technologies 3D</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/informatique-et-applications/debouches">Débouchés</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1766">Génie industriel - Supply chain et numérique</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Génie industriel - Supply chain et numérique</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Ingénieur par apprentissage</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel">Génie industriel - Supply chain et numérique</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel/programme-des-enseignements">Programme des enseignements</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/genie-industriel/debouches">Débouchés</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/mode-emploi">Apprentissage : mode d'emploi</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/admission/Ingenieur-par-apprentissage">Admissions</a></li><li><a href="https://www.esiee.fr/fr/formations/ingenieur-par-apprentissage/site-cergy">Site de Cergy</a></li><li><a href="https://www.esiee.fr/fr/contact-ingenieur-par-apprentissage">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="894">Masters internationaux</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Masters internationaux</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux">Cinq masters internationaux</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/msc-management-information-systems">M.Sc. Management-Information Systems</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/master-computer-science-diplome-ingenieur">International Master of Computer Science</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/master-of-electronics">International Master of Electronics</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux/master-wireless-communicant-sensors">Master of Wireless Communicant Sensors</a></li><li><a href="https://www.esiee.fr/fr/contact-masters-internationaux">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="895">Mastères spécialisés</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Mastères spécialisés</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Formations</a>
# <ul><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises">Mastère spécialisé ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises/innovation-technologique-management-projet">Innovation technologique et management de projets</a></li><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises/admission/Masteres-specialises">Admissions</a></li><li><a href="https://www.esiee.fr/fr/formations/masteres-specialises/frais-de-scolarite">Frais de scolarité mastères spécialisés</a></li><li><a href="https://www.esiee.fr/fr/contact-masteres-specialises">Contact</a></li></ul></div></div></li></ul></div></div></li><li class="espace-etudiants lev0"><a class="js-link-lev0" href="#" id="852">Espace étudiants</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante">La vie étudiante</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1409">L'associatif</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">L'associatif</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Espace étudiants</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/bureau-des-eleves">Bureau des élèves</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/junior-esiee">Junior ESIEE</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/sport">Sport</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/vie-etudiante/clubs-associations">Clubs et associations</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/logements">Logements</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/campus-descartes">Campus Descartes</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/relais-handicap">Relais handicap</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1423">Equipements</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Equipements</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Espace étudiants</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/equipements/centre-de-langues">Le centre de langues</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/equipements/informatique">Informatique</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1462">Bibliothèque</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Bibliothèque</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Espace étudiants</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque">Bibliothèque ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/informations-pratiques">Informations pratiques</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/livres-revues">Livres et revues</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1471">Ressources électroniques</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Ressources électroniques</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Bibliothèque</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/ressources-electroniques">Ressources électroniques</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/ressources-electroniques/sciences-et-techniques">Sciences et techniques</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/informations-entreprises">Informations sur les entreprises</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/ressources-electroniques/presse">Presse</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1467">Services</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Services</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Bibliothèque</a>
# <ul><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/services/aide-personnalise-recherche">Aide personnalisée à la recherche</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/bibliotheque/services/pret-ouvrages">Prêt d'ouvrages</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/contact-biblioth%C3%A8que">Contact</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/videotheque">Vidéothèque</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiants/financer-vos-etudes">Financer vos études</a></li><li><a href="https://www.esiee.fr/fr/espace-etudiant/restauration">Restauration</a></li></ul></div></div></li><li class="ecole lev0"><a class="js-link-lev0" href="#" id="1382">L'école</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/qui-sommes-nous">Qui sommes nous ?</a></li><li><a href="https://www.esiee.fr/fr/gouvernance">Gouvernance</a></li><li><a href="https://www.esiee.fr/fr/ecole/conseil-scientifique">Conseil Scientifique</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1482">Les départements d'enseignements et de recherche</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Les départements d'enseignements et de recherche</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR L'école</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignants/4-departements">4 départements</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/informatique">Informatique</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/ingenierie-systemes">Ingénierie des systèmes</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/sante-energie-environnement">Santé, énergie, environnement</a></li><li><a href="https://www.esiee.fr/fr/ecole/departements-enseignements/management-technologies-langues">Management de la technologie et langues</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1365">Corps enseignant</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Corps enseignant</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR L'école</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/corps-enseignant/enseigner-a-esiee-paris">Enseigner à ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/ecole/les-enseignants-chercheurs">Les enseignants-chercheurs</a></li><li><a href="https://www.esiee.fr/fr/ecole/corps-enseignant/cv-corps-professoral">CV du corps professoral</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1550">Les salles blanches</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Les salles blanches</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR L'école</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches">Les salles blanches</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1064">Equipements et procédés</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Equipements et procédés</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Les salles blanches</a>
# <ul><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes">Équipements et Procédés</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/photolithographie">Photolithographie</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/traitements-thermiques">Traitements thermiques</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/depots-couches-minces">Dépôts de couches minces</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/electrodeposition">Electrodéposition</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/gravures-plasma">Gravures plasma</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/gravure-humide-nettoyage">Gravure humide et nettoyage</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/scellement-de-substrats">Scellement de substrats</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/metrologie">Métrologie</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/plateforme-sem-fib">Plate-forme SEM/FIB</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/packaging">Packaging</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipements-et-procedes/recherche-collaborations">Recherche et collaborations</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/equipe">Equipe</a></li><li><a href="https://www.esiee.fr/fr/ecole/salles-blanches/plateforme-recherche-collaborative-feder">Plateforme de recherche collaborative - FEDER</a></li><li><a href="https://www.esiee.fr/fr/contact-salles-blanches">Contact</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/ecole/esiee-connect/consortium">Le Consortium ESIEE Connect</a></li><li><a href="https://www.esiee.fr/fr/ecole/esiee-connect">ESIEE Connect</a></li></ul></div></div></li><li class="recherche lev0"><a class="js-link-lev0" href="#" id="854">La recherche</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche">Accueil Recherche</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1563">La recherche à ESIEE Paris</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">La recherche à ESIEE Paris</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR La recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/recherche-esiee-paris">La recherche à ESIEE Paris</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/partenariats-academiques">Partenariats académiques</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/partenariats-entreprise">Partenariats entreprise</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1573">Grands domaines</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Grands domaines</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR La recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines">3 grands domaines</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines/ville-durable">Ville durable</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines/sante">Santé</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/grands-domaines/tic-et-societe">STIC et société</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="https://www.esiee.fr/fr/la-recherche" id="1502">Thèmes de recherche</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Thèmes de recherche</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR La recherche</a>
# <ul><li class="with-level"><a class="js-link-lev" href="#" id="1503">Informatique, image, signal</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Informatique, image, signal</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal">Informatique, image, signal</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/architecture-parallelisme-realite-virtuelle">Architecture et parallélisme pour l'imagerie et la réalité virtuelle</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/geometrie-algorithmique">Géométrie discrète, géométrie algorithmique </a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/morphologie-mathematique-traitement-image">Morphologie mathématique et traitement d'images </a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/optimisation-modelisation-apprentissage">Optimisation, modélisation et apprentissage </a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/informatique-image-signal/traitement-signal">Traitement du signal</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1506">Capteurs, santé, énergie, environnement</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Capteurs, santé, énergie, environnement</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement">Capteurs, santé, énergie, environnement</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/microsystemes-analyse-environnement-ville-durable">Microsystèmes pour l'analyse de l'environnement et la ville durable</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/technologies-sante">Technologies pour la santé</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/micro-dispositif-materiaux-nanostructurees-recuperation-energie">Micro-dispositifs et matériaux nanostructurées pour la récupération d'énergie</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/capteurs-sante-energie-environnement/systemes-energetiques-ville-durable">Systèmes énergétiques pour la ville durable</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1508">Electronique, communication</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Electronique, communication</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication">Electronique, communication</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/architectures-algorithmes-communications-radios-localisation">Architectures et algorithmes pour les communications radios et la localisation</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/composants-circuits-systemes-communications-radios-optiques">Composants et circuits pour les systèmes de communications radios et optiques</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/electronique-communication/electronique-micro-systemes-instrumentation-systems-mesures">Electronique associée aux micro-systèmes, instrumentation et systèmes de mesures</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1509">Systèmes embarqués, réseaux, manufacturing</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Systèmes embarqués, réseaux, manufacturing</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing">Systèmes embarqués, réseaux, manufacturing</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/systemes-temps-reel-optimisation-energie">Systèmes temps réel : ordonnancement temps réel, optimisation de l'énergie, méthodologie et outils de conception</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/optimisation-multi-couches-reseaux">Optimisation inter-couches des réseaux</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/systemes-embarques-reseaux-manufacturing/modeles-decisionnels-dynamiques-systemes-manufacturiers">Vers des modèles décisionnels dynamiques pour les systèmes manufacturiers</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1510">Management de l'innovation</a>
# <div class="lev3 js-level">
# <div class="submenu-inner">
# <p class="title">Management de l'innovation</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Thèmes de recherche</a>
# <ul><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation">Management de l'innovation</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/innovations-rupture-marches-connaissance">Innovations de rupture et marchés de la connaissance</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/management-projets-innovants">Management de projets innovants</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/entrepreneuriat-financement-innovation">Entrepreneuriat et financement de l'innovation</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/themes-de-recherche/management-innovation/perpectives-mondialisation-changements-institutionnels">Perspectives de la mondialisation et changements institutionnels</a></li></ul></div></div></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/la-recherche/equipements">Équipements</a></li><li><a href="https://www.esiee.fr/fr/esiee_search/person">Équipe de recherche</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/formations-par-la-recherche">Formations par la recherche</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/formalites-accueil">Formalités d'accueil</a></li><li><a href="https://www.esiee.fr/fr/recherche/actualites">Actualité de la recherche</a></li><li><a href="https://www.esiee.fr/fr/la-recherche/publications-esiee">Publications 2017-2018</a></li><li><a href="https://www.esiee.fr/fr/recherche/publications">Publications avant 2016</a></li><li><a href="https://www.esiee.fr/fr/contact-recherche">Contact</a></li></ul></div></div></li><li class="entreprises lev0"><a class="js-link-lev0" href="#" id="855">Entreprises</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/entreprises">L'entreprise au cœur de l'enseignement</a></li><li class="with-level"><a class="js-link-lev" href="#" id="1397">Recrutez nos étudiants</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Recrutez nos étudiants</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Entreprises</a>
# <ul><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants">Recrutez nos étudiants</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/formations">Formations</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/apprentissage">Apprentissage</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/stages">Stages</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/premier-emploi">1er emploi</a></li><li><a href="https://www.esiee.fr/fr/entreprises/recrutez-nos-etudiants/evenements">Evénements entreprises / étudiants</a></li><li><a href="https://www.esiee.fr/fr/entreprises/deposer-offre-emploi-stage-apprentissage">Déposez une offre d'emploi, de stage et d'apprentissage</a></li><li><a href="https://www.esiee.fr/fr/contact-pole-carriere">Contact</a></li></ul></div></div></li><li class="with-level"><a class="js-link-lev" href="#" id="1406">Devenez partenaire</a>
# <div class="lev2 js-level">
# <div class="submenu-inner">
# <p class="title">Devenez partenaire</p>
# <a class="link-back js-link-back" href="#" title="">RETOUR Entreprises</a>
# <ul><li><a href="https://www.esiee.fr/fr/entreprises/devenez-partenaire/creez-un-partenariat">Créez un partenariat</a></li><li><a href="https://www.esiee.fr/fr/entreprises/devenez-partenaire/recherche-a-esiee-paris">R&amp;D de ESIEE Paris</a></li></ul></div></div></li><li><a href="https://www.esiee.fr/fr/entreprises/formez-vos-equipes">Formez vos équipes</a></li><li><a href="https://www.esiee.fr/fr/entreprises/devenez-partenaire/versez-votre-taxe-apprentissage">Taxe d'apprentissage</a></li><li><a href="https://www.esiee.fr/fr/entreprises/enteprises-mecene">Entreprise mécène</a></li><li><a href="https://www.esiee.fr/fr/entreprises/utilisez-nos-plateformes-technologiques">Utilisez nos plateformes technologiques</a></li><li><a href="https://www.esiee.fr/fr/entreprises/reseau-des-anciens">Réseau des anciens</a></li><li><a href="https://www.esiee.fr/fr/location-despaces">Louez nos espaces</a></li><li><a href="https://www.esiee.fr/fr/contact-entreprises">Contact</a></li><li><a href="https://www.esiee.fr/fr/entreprises/deposer-offre-emploi-stage-apprentissage">Déposez une offre d'emploi, de stage et d'apprentissage</a></li></ul></div></div></li><li class="last international lev0"><a class="js-link-lev0" href="#" id="856">International</a>
# <div class="submenu lev1 js-level js-level1">
# <div class="submenu-inner">
# <a class="link-back js-link-back0 link-back-mob" href="#" title="">RETOUR menu</a>
# <ul><li><a href="https://www.esiee.fr/fr/international/large-ouverture">Une large ouverture à l'international</a></li><li><a href="https://www.esiee.fr/fr/international/partenaires-academiques">Partenaires académiques</a></li><li><a href="https://www.esiee.fr/fr/international/etudier-a-letranger">Etudier à l'étranger</a></li><li><a href="https://www.esiee.fr/fr/international/accueil-etudiants-en-echanges">Etudiants en échange</a></li><li><a href="https://www.esiee.fr/fr/formations/masters-internationaux">Masters internationaux</a></li><li><a href="https://www.esiee.fr/fr/international/reseau-ni">Réseau N+i</a></li><li><a href="https://www.esiee.fr/fr/les-dipl%C3%B4m%C3%A9s-%C3%A0-linternational">Les diplômés à l'international</a></li><li><a href="https://www.esiee.fr/fr/contact-international">Contact </a></li><li><a href="https://www.esiee.fr/fr/campus-%C3%A0-l%C3%A9tranger">Campus à l'étranger</a></li></ul></div></div></li></ul> </div>
# <div class="block block-esiee" id="block-esiee-esiee-header-search">
# <form accept-charset="UTF-8" action="/fr/formations" class="form-horizontal f-left" id="form-search" method="post" onsubmit='if(this.keyword.value == "Rechercher...") this.keyword.value=""'><div> <input class="form-control form-text form-control" id="edit-keyword" maxlength="128" name="keyword" onblur='if(this.value == "") this.value="Rechercher..."' onfocus='if(this.value == "Rechercher...") this.value=""' size="60" type="text" value="Rechercher..."/>
# <input class="form-submit" id="edit-submit--2" name="op" type="submit" value=""/><input name="form_build_id" type="hidden" value="form-wUVTNMqNFRSY3luQAHF5TaX38qYeVGqWXwZHUdJWJc8"/>
# <input name="form_id" type="hidden" value="esiee_global_search_form"/>
# </div></form></div>
# </div>
# </header>
# <section class="clearfix l-main">
# <section class="l-content-top">
# <div class="inner">
# <ul class="breadcrumb breadcrumb-desk"><li><a href="/fr">Accueil</a></li><li class="active">Formations</li></ul>
# <h1>Formations</h1>
# </div>
# </section>
# <div class="tabs inner"></div>
# <div class="block block-bean" id="block-bean-en-tete-formation">
# <div class="inner">
# <div class="content-block-1">
# <div class="content-block-1-txt">
# <p>ESIEE Paris, l’école de l’innovation technologique de la Chambre de commerce et d’industrie de Paris Ile de France, propose des formations au diplôme d’ingénieur (habilité par la commission des titres d’ingénieur - CTI) dans différents domaines<strong>. </strong></p><p>En plus de compétences techniques avérées, les ingénieurs acquièrent de solides notions de management.</p>
# </div>
# </div>
# </div>
# <br/>
# </div>
# <div class="block block-system" id="block-system-main">
# <div class="inner">
# <ul class="cbp_tmtimeline"> <li class="pink">
# <span class="cbp_tmtime">Ingénieur</span>
# <div class="cbp_tmicon"></div>
# <div class="cbp_tmlabel">
# <div class="cbp_tm_img"><!-- scald=520:training_thumbnail --><img alt="Illustration formation ingénieur" height="268" src="https://www.esiee.fr/sites/default/files/styles/formation/public/illustration-formation-ingenieur.jpg?itok=mdrRduFh" title="Illustration formation ingénieur" width="189"/><!-- END scald=520 --></div>
# <p>ESIEE Paris propose : une entrée directement après le baccalauréat pour un cursus intégré en 5 ans ou une entrée en cycle d’ingénieur (après un bac+2) pour une formation en 3 ans. Domaines :  informatique, systèmes d'information, data et réseaux, systèmes embarqués, systèmes électroniques, génie industriel, biotechnologies et e-santé, énergie.</p><ul><li><a href="/fr/formations/ingenieur/ingenieur-esiee-paris">Schéma des études</a></li><li><a href="/fr/formations/ingenieur/premier-cycle">Le premier cycle post-bac en deux ans</a></li><li><a href="/fr/formations/ingenieur/cycle-ingenieur">Le cycle ingénieur en trois ans</a></li><li><a href="/fr/formations/ingenieur/filieres">8 filières de spécialisation réparties en 3 branches</a></li><li><a href="/fr/formations/ingenieur/emplois-et-salaires">Emplois et salaires</a></li></ul><p><strong><a href="/fr/formations/ingenieur/admission/Ingenieur">Admissions</a></strong></p>
# <div class="clearfix"></div>
# </div> </li>
# <li class="turquoise">
# <span class="cbp_tmtime">Ingénieur par apprentissage</span>
# <div class="cbp_tmicon"></div>
# <div class="cbp_tmlabel">
# <div class="cbp_tm_img"><!-- scald=523:training_thumbnail --><img alt="Illustration formations ingénieur apprentissage" height="287" src="https://www.esiee.fr/sites/default/files/styles/formation/public/illustration-formations-ingenieur-apprentissage.jpg?itok=VU--JeBV" title="Illustration formations ingénieur apprentissage" width="189"/><!-- END scald=523 --></div>
# <p>Choisir de poursuivre ses études pour devenir ingénieur se réalise aussi par la voie de l'apprentissage. Quatre filières proposées après un bac+2. Les formations se déroulent sur trois ans.</p><ul><li><a href="/fr/formations/ingenieur-par-apprentissage/reseaux-securite">Filière réseaux et sécurité - <em>Architecture et Internet des objets</em></a></li><li><a href="/fr/formations/ingenieur-par-apprentissage/systemes-embarques">Filière systèmes embarqués - <em>Transports et objets intelligents</em></a></li><li><a href="/fr/formations/ingenieur-par-apprentissage/informatique-et-applications">Filière informatique et applications - <em>Ingénierie 3D et technologies des médias</em></a></li><li><a href="/fr/formations/ingenieur-par-apprentissage/genie-industriel">Filière génie industriel - <em>Supply chain et numérique</em></a></li></ul><p><strong><a href="/fr/formations/ingenieur-par-apprentissage/admission/Ingenieur-par-apprentissage">Admissions</a></strong></p>
# <div class="clearfix"></div>
# </div> </li>
# <li class="purple">
# <span class="cbp_tmtime">Mastères spécialisés</span>
# <div class="cbp_tmicon"></div>
# <div class="cbp_tmlabel">
# <div class="cbp_tm_img"><!-- scald=521:training_thumbnail --><img alt="Illustration formations mastères spécialisés" height="287" src="https://www.esiee.fr/sites/default/files/styles/formation/public/illustration-formation-masteres-specialises.jpg?itok=mAVQyY7P" title="Illustration formations mastères spécialisés" width="189"/><!-- END scald=521 --></div>
# <p>Deux mastères spécialisés sont proposées en formation initiale ou continue (3ème cycle). Ils sont accrédités par la conférence des grandes écoles.</p><ul><li><a href="/fr/formations/masteres-specialises/innovation-technologique-management-projet">Innovation technologique et management de projets</a></li><li><a href="/fr/formations/masteres-specialises/e-sante">e-santé</a></li></ul><p><strong><a href="/fr/formations/masteres-specialises/admission/Masteres-specialises">Admissions</a></strong></p><p> </p>
# <div class="clearfix"></div>
# </div> </li>
# <li class="orange last">
# <span class="cbp_tmtime">Programmes internationaux</span>
# <div class="cbp_tmicon"></div>
# <div class="cbp_tmlabel">
# <div class="cbp_tm_img"><!-- scald=522:training_thumbnail --><img alt="Illustration formations masters internationaux" height="287" src="https://www.esiee.fr/sites/default/files/styles/formation/public/illustration-formation-master-internationaux.jpg?itok=xzN-weZL" title="Illustration formations masters internationaux" width="189"/><!-- END scald=522 --></div>
# <p>Cinq programmes de haut niveau dispensés exclusivement en langue anglaise.</p><ul><li><a href="/fr/formations/masters-internationaux/msc-management-information-systems">M.Sc. Management of Technology - Information Systems</a></li><li><a href="/fr/formations/masters-internationaux/master-computer-science-diplome-ingenieur">International - Filière ingénieur Computer Science</a></li><li><a href="/fr/formations/masters-internationaux/master-of-electronics">International - Filière ingénieur Electronics</a></li><li><a href="/fr/formations/masters-internationaux/master-wireless-communicant-sensors">Master Wireless Communicant Sensors</a></li><li><a href="/fr/international/campus-a-l-etranger/fsati">MSc Electrical and Electronic Systems Engineering - F'SATI (Afrique du Sud)</a></li></ul><p><strong><a href="/en/programmes/international-masters/how-to-apply">Admissions</a></strong></p><p> </p>
# <div class="clearfix"></div>
# </div> </li>
# </ul> </div>
# </div>
# </section>
# <footer>
# <div class="inner clearfix">
# <div class="block block-bean" id="block-bean-adresse-esiee-footer">
# <div class="footer-col-1 pull-left">
# <span class="footer-col-1-title">ESIEE Paris</span>
# <p>2 boulevard Blaise Pascal<br/>Cité Descartes<br/>BP 99<br/>93162 Noisy-le-Grand Cedex</p><p>Tel : 01 45 92 65 00<br/> </p>
# </div></div>
# <div class="block block-esiee" id="block-esiee-esiee-footer-menu">
# <div class="footer-col-2 pull-left">
# <ul class="menu-footer"><li class="first leaf"><a href="/fr/acces">Plan d'accès</a></li>
# <li class="leaf"><a href="/fr/presse">Presse</a></li>
# <li class="leaf"><a href="/fr/nous-rencontrer">Nous rencontrer</a></li>
# <li class="leaf"><a href="/fr/jour-des-projets">Le Jour des Projets</a></li>
# <li class="leaf"><a href="/fr/brochures">Brochures</a></li>
# <li class="leaf"><a href="/fr/videotheque">Vidéothèque</a></li>
# <li class="leaf"><a href="/fr/location-despaces">Location d'espaces</a></li>
# <li class="leaf"><a href="http://www.esiee.fr/fr/ecole/corps-enseignant/enseigner-a-esiee-paris">Enseigner à ESIEE</a></li>
# <li class="leaf"><a href="/fr/reseaux-sociaux">Réseaux sociaux</a></li>
# <li class="leaf"><a href="/fr/mentions-legales">Mentions Légales</a></li>
# <li class="leaf"><a href="http://www.cci-paris-idf.fr/marches-publics-dematerialises-cci-paris-ile-de-france">Marchés publics</a></li>
# <li class="last leaf"><a href="/fr/plan-du-site">Plan du site</a></li>
# </ul></div>
# <div class="clearfix"></div></div>
# <div class="block block-esiee" id="block-esiee-esiee-footer-contact">
# <div class="pull-left"><a class="footer-contact" href="/fr/contact">Contacter ESIEE Paris</a></div></div>
# <div class="block block-bean" id="block-bean-footer-logo-partenaire">
# <div class="pull-right logo-cci">
# <a href="http://www.cci-paris-idf.fr" target="_blank">
# <div class="image"><img alt="logo-cci-paris.png" src="https://www.esiee.fr/sites/default/files/logo-cci-paris.png" title="logo-cci-paris.png"/></div>
# </a></div></div>
# </div>
# </footer>
# </div>
# <div class="toolbar toolbar-footer" id="toolbar-footer">
# <ul>
# <li class="">
# <a href="https://www.facebook.com/esieeparis" target="_blank">
# <i class="fa fa-facebook"></i>
# </a>
# </li>
# <li class="">
# <a href="https://twitter.com/ESIEEPARIS" target="_blank">
# <i class="fa fa-twitter"></i>
# </a>
# </li>
# <li class="">
# <a href="https://www.linkedin.com/edu/school?id=20041&amp;trk=tyah&amp;trkInfo=idx%3A4-1-4%2CtarId%3A1425998561386%2Ctas%3Aesiee+paris" target="_blank">
# <i class="fa fa-linkedin"></i>
# </a>
# </li>
# <li class="youtube">
# <a href="http://www.youtube.com/esieeparis" target="_blank">
# <i class="fa fa-youtube"></i>
# </a>
# </li>
# <li class="">
# <a href="https://www.instagram.com/esieeparis/" target="_blank">
# <i class="fa fa-instagram"></i>
# </a>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# window.jQuery || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/jquery/1.10/jquery.min.js'>\x3C/script>")
# //--><!]]>
# </script>
# <script src="//code.jquery.com/jquery-1.10.2.min.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_vSmhpx_T-AShyt_WMW5_TcwwxJP1imoVOa8jvwL_mxE.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_-DBi72BBkS07mO2sU0Cs9m7v_qf0DaCcgVHrnEXxtcg.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_ajcq4b424tCd76JV2fK93OSs1gAJefWX8KKKtAiej7w.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_P8qUp1A1ztzkIJamZ3ohFgHaPF2ZOo8gXj1zH0XIBtg.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# function euCookieComplianceLoadScripts() {}
# //--><!]]>
# </script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# var eu_cookie_compliance_cookie_name = "";
# //--><!]]>
# </script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_gPqjYq7fqdMzw8-29XWQIVoDSWTmZCGy9OqaHppNxuQ.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", "UA-4033468-1", {"cookieDomain":"auto"});ga("send", "pageview");
# //--><!]]>
# </script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_rO1OpYliXmQPV_bkx6tjJTnc5NHATZQ1P4uSvS9z7LE.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_2PmUXh0PE5NzhnjBZseSzCTfPzCIsMn5irM9A2r3Y4c.js" type="text/javascript"></script>
# <script src="https://www.esiee.fr/sites/default/files/js/js_6KurW8SbFvAKc4Ke5ypFvfbGMSJnBh0H6QlA2mVtSbM.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"fr\/","ajaxPageState":{"theme":"esiee_theme","theme_token":"2GDCHEQkZlKq6NT2xnl13XHGJ7MRqiWizoJIWNH7Rt8"},"googleCSE":{"cx":"","language":"","resultsWidth":600,"domain":"www.google.com"},"urlIsAjaxTrusted":{"\/fr\/formations":true},"eu_cookie_compliance":{"popup_enabled":1,"popup_agreed_enabled":0,"popup_hide_agreed":0,"popup_clicking_confirmation":false,"popup_scrolling_confirmation":false,"popup_html_info":"\u003Cdiv\u003E\n  \u003Cdiv class =\u0022custom-cookie-popup popup-content info\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\n      \u003Cp\u003EEn naviguant sur notre site, vous acceptez l\u0026#39;utilisation de cookies pour vous proposer une navigation optimale et nous permettre de r\u00e9aliser des statistiques de visites. Pour en savoir plus et param\u00e9trer les cookies, visiter \u003Ca href=\u0022\/fr\/mentions-legales\u0022\u003Ela page des mentions l\u00e9gales de ESIEE Paris\u003C\/a\u003E\u003C\/p\u003E    \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button\u0022\u003EAccepter\u003C\/button\u003E\n    \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","use_mobile_message":false,"mobile_popup_html_info":"\u003Cdiv\u003E\n  \u003Cdiv class =\u0022custom-cookie-popup popup-content info\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\n          \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button\u0022\u003EAccepter\u003C\/button\u003E\n    \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E\n","mobile_breakpoint":"768","popup_html_agreed":"\u003Cdiv\u003E\r\n  \u003Cdiv class =\u0022popup-content agreed\u0022\u003E\r\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\r\n      \u003Ch2\u003EThank you for accepting cookies\u003C\/h2\u003E\u003Cp\u003EYou can now hide this message or find out more about cookies.\u003C\/p\u003E    \u003C\/div\u003E\r\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\r\n      \u003Cbutton type=\u0022button\u0022 class=\u0022hide-popup-button eu-cookie-compliance-hide-button\u0022\u003EMasquer\u003C\/button\u003E\r\n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button-thank-you\u0022 \u003EMore info\u003C\/button\u003E\r\n          \u003C\/div\u003E\r\n  \u003C\/div\u003E\r\n\u003C\/div\u003E","popup_use_bare_css":false,"popup_height":"auto","popup_width":"100%","popup_delay":1000,"popup_link":"\/fr\/fr\/fr\/mentions-legales","popup_link_new_window":1,"popup_position":null,"popup_language":"fr","store_consent":true,"better_support_for_screen_readers":0,"reload_page":0,"domain":"","popup_eu_only_js":0,"cookie_lifetime":"100","cookie_session":false,"disagree_do_not_show_popup":0,"method":"opt_in","whitelisted_cookies":"","withdraw_markup":"\u003Cbutton type=\u0022button\u0022 class=\u0022eu-cookie-withdraw-tab\u0022\u003E\u003C\/button\u003E\r\n\u003Cdiv class=\u0022eu-cookie-withdraw-banner\u0022\u003E\r\n  \u003Cdiv class=\u0022popup-content info\u0022\u003E\r\n    \u003Cdiv id=\u0022popup-text\u0022\u003E\r\n          \u003C\/div\u003E\r\n    \u003Cdiv id=\u0022popup-buttons\u0022\u003E\r\n      \u003Cbutton type=\u0022button\u0022 class=\u0022eu-cookie-withdraw-button\u0022\u003E\u003C\/button\u003E\r\n    \u003C\/div\u003E\r\n  \u003C\/div\u003E\r\n\u003C\/div\u003E\r\n","withdraw_enabled":false},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"},"esiee_scholarship":{"max_80":5000,"quotient_80":60,"min_60":5001,"max_60":7000,"quotient_60": ...
# //--><!]]>
# </script>
# <script src="https://code.jquery.com/jquery-migrate-1.2.1.js"></script>
# </body>
# </html>}

# %% [markdown]
# # Exploitation des appels d'API

# %% [markdown]
# Losque le front du site récupère des données sur une API géré par le back, un appel d'API est réalisé. Cet appel est recensé dans les appels réseaux. Il est alors possible de re-jouer cet appel pour récupérer à nouveau les données. Il est très facile de récupérer ces appels dans l'onglet Network de la console développeur de Chrome ou FireFox. La console vous permet de copier le code CURL pour effectuée et vous pouvez ensuite la transformer en code Python depuis le site https://curl.trillworks.com/.
#
# Souvent les APIs sont bloquées avec certain paramètres. L'API verifie que dans les headers de la requêtes HTTP ces paramètres sont présents : * un token généré à la volée avec des protocole OAuth2 (ou moins développés). * un referer provenant du site web (la source de la requête), très facile à falsifier.

# %% [markdown]
# ## Exercice
# ### Exercice 4
#
# - Utiliser les informations développées plus haut pour récupérer les premiers résultats d'une recherche d'une requête
# sur Qwant.
#
# Tips :
#
# - Aller sur https://www.qwant.com/
# - Ouvrir les outils de développements de Chrome ou Firefox
# - Onglet Network
# - Fouiller dans les requêtes

# %% [markdown]
# >> aller sur qwant, faire une recherche "tennis"
# ouvrir la console > network > XHR > webcount > clic droit copy as curl > convertir
# xhr correspond aux data

# %%
import requests

headers = {
    'Origin': 'https://www.qwant.com',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36',
    'Content-type': 'application/x-www-form-urlencoded',
    'Accept': '*/*',
    'Referer': 'https://www.qwant.com/',
    'Connection': 'keep-alive',
}

params = (
    ('count', '10'),
    ('q', 'tennis'),
    ('t', 'web'),
    ('device', 'desktop'),
    ('safesearch', '1'),
    ('locale', 'fr_FR'),
    ('uiv', '4'),
)

response = requests.get('https://api.qwant.com/api/search/web', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://api.qwant.com/api/search/web?count=10&q=tennis&t=web&device=desktop&safesearch=1&locale=fr_FR&uiv=4', headers=headers)

# %%
response.json()
# Out:
# {'status': 'success',
#  'data': {'query': {'locale': 'fr_fr', 'query': 'tennis', 'offset': 0},
#   'cache': {'key': '9ab20aba52cb9c88e9421a726d4ced52',
#    'created': 1543817899,
#    'expiration': 604800,
#    'status': 'hits',
#    'age': 186206,
#    'version': 1,
#    'system': 'R',
#    'mode': 3},
#   'result': {'total': 49,
#    'items': [{'title': '<b>Tennis</b> : résultats <b>tennis</b> et classement en live ATP des ...',
#      'favicon': '//s.qwant.com/fav/e/u/www_eurosport_fr.ico',
#      'url': 'https://www.eurosport.fr/tennis/',
#      'source': 'https://www.eurosport.fr/<b>tennis</b>',
#      'desc': "Retrouvez toute l'actualité du <b>tennis</b> en direct et en vidéos sur Eurosport",
#      '_id': '191ba8a9cae76aa35d7defe113c33881',
#      'position': 1},
#     {'title': '<b>Tennis</b> : Actualités, calendriers et résultats ATP WTA ...',
#      'favicon': '//s.qwant.com/fav/l/e/www_lequipe_fr.ico',
#      'url': 'https://www.lequipe.fr/Tennis/',
#      'source': 'https://www.lequipe.fr/<b>Tennis</b>',
#      'desc': "Toute l'actualité du <b>tennis</b> est à suivre en direct sur L'Équipe. Découvrez les dernières informations, résultats, classements ainsi que les directs commentés des plus belles affiches.",
#      '_id': 'e7a4399a2f58b993d74bc3810a9ee94a',
#      'position': 2},
#     {'title': '<b>Tennis</b> — Wikipédia',
#      'favicon': '//s.qwant.com/fav/w/i/fr_wikipedia_org.ico',
#      'url': 'https://fr.wikipedia.org/wiki/Tennis',
#      'source': 'https://fr.wikipedia.org/wiki/<b>Tennis</b>',
#      'desc': 'Le <b>tennis</b> est un sport de raquette qui oppose soit deux joueurs (on parle alors de jeu en simple) soit quatre joueurs qui forment deux équipes de deux (on parle alors de jeu en double).',
#      '_id': '9112afd7621840827c3d7d426060bae6',
#      'position': 3},
#     {'title': '<b>Tennis</b>, Roland Garros, <b>Tennis</b> en direct, Résultats ATP ...',
#      'favicon': '//s.qwant.com/fav/s/p/www_sports_fr.ico',
#      'url': 'http://www.sports.fr/tennis/',
#      'source': 'www.sports.fr/<b>tennis</b>',
#      'desc': "Suivez en direct l'Open d'Australie et les résultats, les classements ATP et le classement WTA. L'actualité du <b>tennis</b>, Roland-Garros, Wimbledon, US Open, Open d'Australie, Monte Carlo, Paris ...",
#      '_id': 'b83d273fadcbfee2e15e79f2751d9d20',
#      'position': 4},
#     {'title': '<b>Tennis</b> : Actualité ATP WTA - Scores de <b>Tennis</b> en Direct',
#      'favicon': '//s.qwant.com/fav/l/i/www_livetennis_fr.ico',
#      'url': 'http://www.livetennis.fr/',
#      'source': 'www.live<b>tennis</b>.fr',
#      'desc': 'Livescore en direct de <b>tennis</b>, tournois ATP, tournois WTA, grand chelem, Coupe Davis, Fed Cup, Roland Garros, Wimbledon, US Open, Melbourne etc...',
#      '_id': 'de4c8bd0fe6450dac5e1b55e1c104dc9',
#      'position': 5},
#     {'title': 'Les matchs en direct de <b>tennis</b>, résultats <b>tennis</b> et ...',
#      'favicon': '//s.qwant.com/fav/l/e/www_lequipe_fr.ico',
#      'url': 'https://www.lequipe.fr/Tennis/Directs',
#      'source': 'https://www.lequipe.fr/<b>Tennis</b>/Directs',
#      'desc': "Suivez les matches de <b>tennis</b> en direct, les résultats en live et les commentaires des journalistes de l'Equipe.",
#      '_id': 'de3b90f9f62914a0259e60e992cfe815',
#      'position': 6},
#     {'title': '<b>TENNIS</b>.com - Live Scores, News, Player Ranking',
#      'favicon': '//s.qwant.com/fav/t/e/www_tennis_com.ico',
#      'url': 'http://www.tennis.com/',
#      'source': 'www.<b>tennis</b>.com',
#      'desc': '<b>TENNIS</b>.com - Live Scores, <b>Tennis</b> News, Player Ranking, and Complete Tournament Data.',
#      '_id': '42c46a154feb4ae0c0d6e5b4b8bc8df4',
#      'position': 7},
#     {'title': '<b>Tennis</b> actualité, classement, calendrier et résultats',
#      'favicon': '//s.qwant.com/fav/o/r/sports_orange_fr.ico',
#      'url': 'https://sports.orange.fr/tennis/',
#      'source': 'https://sports.orange.fr/<b>tennis</b>',
#      'desc': "<b>Tennis</b> - Toute l'actualité avec les calendriers, les résultats, les news pour ne rien manquer de l'actu sportive",
#      '_id': '2ded8ab8d643019d9fc57ffd5f725e83',
#      'position': 8},
#     {'title': '<b>Tennis</b> en direct - <b>Tennis</b> live, Résultats, Classements ATP ...',
#      'favicon': '//s.qwant.com/fav/f/l/www_flashresultats_fr.ico',
#      'url': 'http://www.flashresultats.fr/tennis/',
#      'source': 'www.flashresultats.fr/<b>tennis</b>',
#      'desc': 'Résultats de <b>tennis</b> en direct. Matchs de <b>tennis</b> en direct live sur FlashResultats.fr. Scores de <b>tennis</b> pour plus de 2000 tournois ATP, WTA et plus encore. Les classements ATP et WTA !',
#      '_id': '2aaab5e7873748f108f28f9511aa07ad',
#      'position': 9},
#     {'title': '<b>Tennis</b> Temple - Le <b>tennis</b> en direct',
#      'favicon': '//s.qwant.com/fav/t/e/fr_tennistemple_com.ico',
#      'url': 'https://fr.tennistemple.com/',
#      'source': 'https://fr.<b>tennis</b>temple.com',
#      'desc': 'Tout le <b>tennis</b> en direct, Les résultats ATP et WTA, les news, les tableaux, le calendrier, les classements et tous les matchs.',
#      '_id': 'b18bbf0d96d0f62608f11465ffa1d916',
#      'position': 10}],
#    'filters': {'freshness': {'label': 'Freshness',
#      'name': 'freshness',
#      'type': 'dropdown',
#      'selected': 'all',
#      'values': [{'value': 'all', 'label': 'All time', 'translate': True},
#       {'value': 'day', 'label': 'Past 24 hours', 'translate': True},
#       {'value': 'week', 'label': 'Past week', 'translate': True},
#       {'value': 'month', 'label': 'Past month', 'translate': True}]}},
#    'version': 'B',
#    'ads': []}}}

# %% [markdown]
# # Exercice Final

# %% [markdown]
# Exercice Final
# Utilisez tout ce que vous avez appris pour récupérer des articles de News avec une catégorie. Il est souvent intéressant de partir des flux RSS pour commencer :
#
# Les données doivent comprendre :
# - Le texte important propre
# - L'url
# - Le domaine
# - la catégorie
# - Le titre de l'article
# - Le titre de la page
# - (Facultatif) : les images
#
# Tips :
#
# - Taper le nom de votre média favoris + RSS (par exemple : https://www.lemonde.fr/rss/)
# - Aller dans le DOM de la page
# - Trouver les catégories et les liens vers les articles

# %%
import random

def get_articles(url_category):
    article = {}
    
    userAgents = [
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.113 Safari/537.36",
        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36",
        "Mozilla/5.0 (Linux; Android 5.1; A37f Build/LMY47V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.93 Mobile Safari/537.36",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36"
    ]
    
    x = http_request(url_category, random.choice(userAgents))
    x.url
    soup = x.soup_url()
    article["text"] = soup
    article["url"] = url_category
    return article

# %%
article = get_articles("https://www.lemonde.fr/ameriques/rss_full.xml")
print(article)
# Out:
# {'text': <?xml version="1.0" encoding="utf-8"?><html><body><rss version="2.0" xmlns:atom="https://www.w3.org/2005/Atom">
# <channel>
# <title>AmÃ©riques : Toute l'actualitÃ© sur Le Monde.fr.</title>
# <description>AmÃ©riques - DÃ©couvrez gratuitement tous les articles, les vidÃ©os et les infographies de la rubrique AmÃ©riques sur Le Monde.fr.</description>
# <copyright>Copyright Le Monde.fr</copyright>
# <link/>https://www.lemonde.fr/ameriques/rss_full.xml
#     <atom:link href="https://www.lemonde.fr/ameriques/rss_full.xml" rel="self" type="application/rss+xml"></atom:link>
# <pubdate>Wed, 05 Dec 2018 11:21:09 +0100</pubdate>
#
# <url>https://www.lemonde.fr/medias/web/img/export/logo_lmfr_90x20_export.png</url>
# <title>AmÃ©riques : Toute l'actualitÃ© sur Le Monde.fr.</title>
# <link/>https://www.lemonde.fr/ameriques/rss_full.xml
#
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/05/prudente-sur-l-ukraine-l-otan-met-la-russie-au-pied-du-mur-sur-le-traite-fni_5392896_3210.html
#       <title>Prudente sur lâUkraine, lâOTAN met la Russie au pied du mur sur le traitÃ© FNI</title>
# <description>Les AlliÃ©s veulent inciter Moscou Ã  respecter le traitÃ© de 1987 sur les forces nuclÃ©aires Ã  portÃ©e intermÃ©diaire.</description>
# <pubdate>Wed, 05 Dec 2018 10:42:42 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392896/</guid>
# <enclosure length="32781" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392894_3_9d07_le-secretaire-d-etat-americain-mike-pom_25a80e3e487fbbd5b9d7779eac60bccd.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/05/en-colombie-les-assassinats-cibles-de-leaders-sociaux-augmentent_5392870_3210.html
#       <title>En Colombie, les assassinats ciblÃ©s de Â«Â leaders sociauxÂ Â» augmentent</title>
# <description>Depuis le dÃ©but de lâannÃ©e, 230 dÃ©fenseurs des droits de lâhomme et de lâenvironnement ont Ã©tÃ© assassinÃ©s.</description>
# <pubdate>Wed, 05 Dec 2018 10:10:34 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392870/</guid>
# <enclosure length="28154" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392868_3_cdbd_le-rapporteur-special-des-nations-unies-sur-la_daad29f3642ea8e420e6842bda209520.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/05/affaire-russe-l-aide-substantielle-de-michael-flynn-soulignee_5392690_3210.html
#       <title>Affaire russeÂ : Â«Â lâaide substantielleÂ Â» de Michael Flynn soulignÃ©e</title>
# <description>Le procureur spÃ©cial chargÃ© de lâenquÃªte a recommandÃ© mardi une peine sans dÃ©tention pour lâÃ©phÃ©mÃ¨re conseiller Ã  la sÃ©curitÃ© nationale de Donald Trump.</description>
# <pubdate>Wed, 05 Dec 2018 04:45:22 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392690/</guid>
# <enclosure length="33071" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392689_3_6ba6_michael-flynn-a-ete-conseiller-a-la-se_553f81bdb380ae116793cfed748f81bc.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/05/khashoggi-l-audition-de-la-directrice-de-la-cia-conforte-la-volonte-de-sanction-du-senat-americain_5392685_3210.html
#       <title>KhashoggiÂ : lâaudition de la directrice de la CIA conforte la volontÃ© de sanction du SÃ©nat amÃ©ricain</title>
# <description>Le prÃ©sident rÃ©publicain de la commission des affaires Ã©trangÃ¨res a estimÃ© que si le prince hÃ©ritier saoudien Ã©tait devant un tribunal, Â«Â il serait reconnu coupable en trente minutesÂ Â».</description>
# <pubdate>Wed, 05 Dec 2018 03:27:37 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392685/</guid>
# <enclosure length="40427" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392684_3_785f_le-president-republicain-de-la-commission-des-a_58546f7570b64c8c2b08be561fb3bb21.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/economie/article/2018/12/05/la-courbe-des-taux-d-inverse-aux-etats-unis-wall-street-panique_5392682_3234.html
#       <title>La courbe des taux sâinverse aux Etats-Unis, Wall Street panique</title>
# <description>Si la tendance se poursuit, il va bientÃ´t coÃ»ter plus cher dâemprunter Ã  court terme quâÃ  long terme outre-Atlantique.</description>
# <pubdate>Wed, 05 Dec 2018 03:18:27 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392682/</guid>
# <enclosure length="40883" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392681_3_7c11_a-l-etage-du-new-york-stock-exchange-le-3-de_e7a446dea8a2c9e630da29087cd81d76.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/05/etats-unis-la-justice-reclame-des-documents-sur-le-trump-hotel_5392670_3210.html
#       <title>Etats-UnisÂ : la justice rÃ©clame des documents sur le Trump Hotel</title>
# <description>Cette requÃªte sâinscrit dans le cadre dâune enquÃªte pour corruption portant sur les revenus perÃ§us par son Ã©tablissement de Washington auprÃ¨s dâofficiels Ã©trangers.</description>
# <pubdate>Wed, 05 Dec 2018 00:54:12 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392670/</guid>
# <enclosure length="59845" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392669_3_9e49_la-facade-du-trump-international-hotel-a-w_304050bfcf6d867bf2f73911b2320077.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/afrique/article/2018/12/05/retour-de-la-diplomatie-americaine-en-somalie-apres-28-ans-d-absence_5392667_3212.html
#       <title>Retour de la diplomatie amÃ©ricaine en Somalie, aprÃ¨s vingt-huit ans dâabsence</title>
# <description>Lâambassade des Etats-Unis dans le pays avait Ã©tÃ© fermÃ©e et Ã©vacuÃ©e en janvierÂ 1991, face Ã  la violence et Ã  lâeffondrement du gouvernement central.</description>
# <pubdate>Wed, 05 Dec 2018 00:05:28 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392667/</guid>
# <enclosure length="70495" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/05/644x322/5392666_3_def9_en-decembre-1992-dans-la-capitale-somalienne_fdff98aabedadfe65bb3eb59fd0314c6.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/televisions-radio/article/2018/12/04/thomas-pesquet-chez-les-kogui-un-spationaute-en-terre-inconnue_5392642_1655027.html
#       <title>Â«Â Thomas Pesquet chez les KoguiÂ Â» : un spationaute en terre inconnue</title>
# <description>Thomas Pesquet et FrÃ©dÃ©ric Lopez vont Ã  la rencontre dâune tribune indienne dans le nord de la Colombie.</description>
# <pubdate>Tue, 04 Dec 2018 19:30:30 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392642/</guid>
# <enclosure length="55387" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/04/644x322/5392640_3_f12c_chez-les-kogis-dans-la-sierra-nevada-en-colombie_de916fc937109250cbf50c9fde64a087.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/pixels/article/2018/12/04/sur-internet-et-dans-les-medias-la-droite-americaine-se-delecte-de-la-crise-des-gilets-jaunes_5392379_4408996.html
#       <title>Sur Internet et dans les mÃ©dias, la droite amÃ©ricaine se dÃ©lecte de la crise des Â«Â gilets jaunesÂ Â»</title>
# <description>Les images de violences en France sont vues comme une validation de la posture de Donald Trump, et un moyen de critiquer Emmanuel Macron, que beaucoup exÃ¨crent.</description>
# <pubdate>Tue, 04 Dec 2018 10:37:39 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392379/</guid>
# <enclosure length="44606" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/04/644x322/5392375_3_db87_des-gilets-jaunes-a-frontignan-dans-l-he_12a17b9b559a5f78225f480b3bd5adee.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/affaire-khashoggi/article/2018/12/04/la-cheffe-de-la-cia-va-informer-des-parlementaires-sur-le-meurtre-de-khashoggi_5392229_5390206.html
#       <title>La chef de la CIA va informer des parlementaires sur le meurtre de Khashoggi</title>
# <description>MmeÂ Haspel nâavait pas rÃ©pondu Ã  lâinvitation des sÃ©nateurs, qui avaient entendu Ã  huis clos fin novembre, les ministres de la dÃ©fense et des affaires Ã©trangÃ¨res sur ce dossier.</description>
# <pubdate>Tue, 04 Dec 2018 03:33:33 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392229/</guid>
# <enclosure length="23827" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/04/644x322/5392228_3_889f_la-directrice-de-la-cia-gina-haspel-lors-de_bc59fb7f293638a531996c706eb2fc33.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/04/mexique-creation-d-une-commission-d-enquete-sur-la-disparition-de-43-etudiants-en-2014_5392226_3210.html
#       <title>MexiqueÂ : crÃ©ation dâune commission dâenquÃªte sur la disparition de 43Â Ã©tudiants enÂ 2014</title>
# <description>Le prÃ©sident Lopez Obrador a promis une rupture avec le passÃ© sur cette affaire qui avait entachÃ© le mandat de son prÃ©dÃ©cesseur et dÃ©clenchÃ© un scandale international.</description>
# <pubdate>Tue, 04 Dec 2018 02:47:32 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5392226/</guid>
# <enclosure length="55514" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/04/644x322/5392225_3_9afc_les-proches-des-43-disparus-d-ayotzinapa-br_fa7f79a3145e7b936bff7fd472e1df13.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/idees/article/2018/12/03/le-plus-etonnant-dans-la-chute-de-facebook-est-peut-etre-que-l-on-s-en-etonne_5391859_3232.html
#       <title>Â«Â Le plus Ã©tonnant dans la chute de Facebook est peut-Ãªtre que lâon sâen Ã©tonneÂ Â»</title>
# <description>Dans sa chronique, lâÃ©conomiste Paul Jorion estime que les limites du Â« business plan Â» du rÃ©seau social menacent lâavenir de son ambitieux dirigeant Mark Zuckerberg.</description>
# <pubdate>Mon, 03 Dec 2018 09:19:00 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391859/</guid>
# <enclosure length="22877" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/03/644x322/5391858_3_bd27_le-dirigeant-et-fondateur-de-facebook-mark_4aa1e38e3989752548c0e4a261607235.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/03/fragile-treve-entre-les-etats-unis-et-la-chine_5391845_3210.html
#       <title>Fragile trÃªve entre les Etats-Unis et la Chine</title>
# <description>Donald Trump et Xi Jinping ont suspendu les hostilitÃ©s commerciales en marge du G20, mais les sujets de friction demeurent.</description>
# <pubdate>Mon, 03 Dec 2018 08:56:18 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391845/</guid>
# <enclosure length="52768" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/03/644x322/5391844_3_53fd_le-president-chinois-xi-jinping-lors-du-diner-d_1a0abccc4f6921380669112b58926810.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/economie/article/2018/12/03/luciano-hang-l-entrepreneur-bresilien-qui-se-reve-en-trump_5391810_3234.html
#       <title>Luciano Hang, le patron brÃ©silien prÃªt Ã  tout pour soutenir Bolsonaro</title>
# <description>Avec ses vidÃ©os et messages sans nuances, le fondateur des magasins Havan a menÃ© campagne pour le nouveau prÃ©sident dâextrÃªme droite.</description>
# <pubdate>Mon, 03 Dec 2018 06:36:17 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391810/</guid>
# <enclosure length="29485" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/03/644x322/5391809_3_b901_le-president-de-havan-luciano-hang-lors_970fadf695e6bd58864c860990bda57b.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/02/donald-trump-veut-mettre-fin-a-l-alena-rapidement_5391562_3210.html
#       <title>Donald Trump veut Â«Â mettre finÂ Â» Ã  lâAlÃ©na rapidement</title>
# <description>Le prÃ©sident amÃ©ricain souhaite voir disparaÃ®tre lâaccord de libre-Ã©change remontant Ã  1994 avec le Mexique et le Canada, quâil qualifie rÃ©guliÃ¨rement de Â«Â pire accord jamais signÃ©Â Â», en faveur du nouveau traitÃ© nÃ©gociÃ© difficilement avec ses voisins nord-amÃ©ricains ces derniers mois.</description>
# <pubdate>Sun, 02 Dec 2018 10:05:16 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391562/</guid>
# <enclosure length="43692" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/02/644x322/5391560_3_c72f_de-gauche-a-droite-les-chefs-d-etat-me_83f63e893b6f303a0935f5428a3ec9d6.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/02/amlo-lance-sa-transformation-du-mexique_5391543_3210.html
#       <title>Â«Â AMLOÂ Â» lance sa transformation du Mexique</title>
# <description>Education et santÃ© gratuites, hausse du salaire minimum, bourses scolairesÂ : Ã  peine investi, le prÃ©sident Andres Manuel Lopez Obrador a listÃ© les mesures quâil entend prendre pour redresser le pays</description>
# <pubdate>Sun, 02 Dec 2018 07:36:12 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391543/</guid>
# <enclosure length="39523" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/02/644x322/5391540_3_5406_le-nouveau-president-du-mexique-andres-m_b7327c3772a3b10154e9206fb6d0de06.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/02/andres-manuel-lopez-obrador-intronise-president-du-mexique_5391482_3210.html
#       <title>AndrÃ©s Manuel Lopez Obrador intronisÃ© prÃ©sident du Mexique</title>
# <description>Le nouveau chef dâEtat a promis de lutter contre la corruption en menant une transformation Â«Â profonde et radicaleÂ Â» du pays.</description>
# <pubdate>Sun, 02 Dec 2018 05:36:42 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391482/</guid>
# <enclosure length="62976" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/02/644x322/5391480_3_f2d4_le-president-mexicain-a-ete-intronise-par-un-r_18a9baed011ce44c669a66bbf5580bfe.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/international/article/2018/12/02/la-chine-et-les-etats-unis-s-entendent-sur-une-treve-dans-leur-guerre-commerciale_5391479_3210.html
#       <title>La Chine et les Etats-Unis sâentendent sur une trÃªve dans leur guerre commerciale</title>
# <description>Lors dâun dÃ®ner de travail, Donald Trump et Xi Jinping ont trouvÃ© un accord pour ne pas appliquer de nouveaux droits de douaneÂ aprÃ¨s le 1erÂ janvier.</description>
# <pubdate>Sun, 02 Dec 2018 04:40:38 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391479/</guid>
# <enclosure length="52792" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/02/644x322/5391478_3_84a0_la-rencontre-entre-donald-trump-et-son_f70903eb1f8c6461ebb56d76d97701fa.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/chroniques-de-la-presidence-trump/article/2018/12/01/l-hommage-de-trump-a-bush-deux-hommes-que-tout-oppose_5391372_5077160.html
#       <title>Lâhommage de Trump Ã  Bush, deux hommes que tout oppose</title>
# <description>Lâactuel locataire de la Maison Blanche a annulÃ© sa confÃ©rence de presse au G20 samedi, Â«Â par respectÂ Â» pour la famille de lâancien prÃ©sident, mort vendredi Ã  lâÃ¢ge de 94Â ans.</description>
# <pubdate>Sat, 01 Dec 2018 18:05:59 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391372/</guid>
# <enclosure length="32074" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/01/644x322/5391371_3_eb1e_le-president-trump-rend-hommage-a-l-ancien-pre_127b8be7197088ec9afb0d3af5afdcb1.jpg"></enclosure>
# </item>
# <item>
# <link/>https://www.lemonde.fr/planete/article/2018/12/01/incendie-en-californie-le-nombre-de-personnes-disparues-revu-largement-a-la-baisse_5391342_3244.html
#       <title>Incendie en CalifornieÂ : le nombre de personnes disparues revu largement Ã  la baisse</title>
# <description>Les autoritÃ©s ont ramenÃ© Ã  49 le nombre de disparus dans lâincendie Â«Â Camp FireÂ Â», aux Etats-Unis. Le feu a fait 88 morts.</description>
# <pubdate>Sat, 01 Dec 2018 14:49:33 +0100</pubdate>
# <guid ispermalink="true">https://www.lemonde.fr/tiny/5391342/</guid>
# <enclosure length="53116" type="image/jpeg" url="https://s1.lemde.fr/image/2018/12/01/644x322/5391340_3_934f_une-decoration-de-noel-dans-un-magasin-d_f791c6b03f4c0e34c16d4a0082f0b617.jpg"></enclosure>
# </item>
# </channel>
# </rss>
# </body></html>, 'url': 'https://www.lemonde.fr/ameriques/rss_full.xml'}
